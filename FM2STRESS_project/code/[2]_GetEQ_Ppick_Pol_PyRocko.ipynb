# %% [markdown]
# # Earthquake Data Download, Phase Picking, Polarity and Focal Mechanism Determination
# This notebook will select earthquake events from the USGS catalogs subset made in part-1 for above slab events.
# Then download the `mseed` file and associated `inventory (txt)` files for each events for events in the study area.
# Since this is a fairly small study area start time of 30s before the event time will be enough for the most distant ones as well.
# Next, I will use `PhaseNet` and `Pyrocko` to pick P and S phases and their polarity.
# Lastly, I will use `HASH(fortran)` and `SKHASH (python)` to determine the focal mechanisms.
#
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ### Import all necessary libraries here, this will make things easier later

# %%
import os
import sys
import time
from tqdm.auto import tqdm
import glob
# from joblib import Parallel, delayed
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from obspy.clients.fdsn import Client
from obspy import UTCDateTime, read_inventory, Inventory, read, Stream
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import backend as K

sys.path.append('./my_funcs')
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# my custom functions
from get_waveforms_parallel_v3 import get_waveforms_parallel, get_station_inventory

# %% [markdown]
# # Setup all directories

# %%
# set up the project directory
project_dir = f"{os.getcwd()}/../"
data_dir = os.path.join(project_dir, "data/eq_data") # include data folders for eq catalogs, waveforms, and station catalogs
catalog_dir = os.path.join(data_dir, "1_eq_catalogs") # all eq catalogs: orig and edited
waveform_dir = os.path.join(data_dir, "2_waveforms") # mseed files
station_dir = os.path.join(data_dir, "3_station_catalogs") # station xml files

pn_dt_dir = os.path.join(project_dir, "results/phasenet_diting_others") # dir for phasenet,diting,pyrocko
pn_dir = os.path.join(pn_dt_dir, "phasenet_files") # phasenet picks [+added diting & manual picks]
os.makedirs(pn_dir, exist_ok=True)

cwd = os.getcwd()
phasenet_path = f"{cwd}/../../../../Software_docs/PhaseNet" # path to source code of PhaseNet

# %% [markdown]
# # (1) Select desired events from the catalog. To get a good spatial distribution I divided the study area into grids of 0.2 degrees.
# Now, I select the highest magnitude events from each grid.
# Also check if the depth is `artificial` i.e, a given value of 5, 10, 15 or 20 km when depth constrain is bad.

# %%
eq_cat_file = os.path.join(catalog_dir, "usgs_3D_gridsort_eq_above_slab2_area.csv")

eqdf = pd.read_csv(eq_cat_file, parse_dates=["time"])
eqdf = eqdf[eqdf.mag >= 2.5].reset_index(drop=True)

# %%
# Extract unique grid codes and sort them
unique_grid_codes = np.sort(eqdf['grid_code_3D'].unique())
print(f"Number grids with eq : {len(unique_grid_codes)}")

# create an empty dataframe to store the selected events
selected_eq = pd.DataFrame(columns=eqdf.columns)

# Loop through each grid code and select the event with the highest magnitude
for grid_code in unique_grid_codes:
    temp_df = eqdf[eqdf['grid_code_3D'] == grid_code].sort_values(by='mag', ascending=False)
 
    # Check if there are events in the grid
    if len(temp_df) > 0:
        # print(temp_df[['id', 'mag', 'time']])
        # check the depth values if 0 or 5 or 10 km fixed depth, select the next event
        for i, row in temp_df.iterrows():
            if row['depth'] == 0 or row['depth'] == 5 or row['depth'] == 10:
                print(f"Event {row['id']} has depth {row['depth']} km, selecting next event")
                continue
            else:
                selected_eq = pd.concat([selected_eq, row.to_frame().T], ignore_index=True)
                break

# save the selected events
selected_eq.to_csv(f"{catalog_dir}/selected_eq{len(selected_eq)}.csv", index=False)
print(f"Number of selected events : {len(selected_eq)}")
# Out:
# Number grids with eq : 105
# Number of selected events : 105

# %% [markdown]
#  # (2) Download the inventory data for the following criterias
#
# Get the station inventory within the study area which recorded this event.\
# Use this station inventory data to download earthquake data (`.mseed`) and station data (`.txt` or `.xml` format).\
# 3-channel data for earthquakes are along x, y and z axis. Usually named as HHE, HHN and HHZ or HH1, HH2, HHZ.\
# I want to select the following channels in order. If the 1st one is available, get that one only and stop. If not search for the 2nd one and so on.
# 1. HH*
# 2. BH*
# 3. HN*
# 4. EH* \
# Lastly, of stations within the study area (+0.5 degrees) for each of the selected events.

# %% [markdown]
# ## 2.1 Make a master inventory file
# As we select events from 2008 to end of 2023, a master station inventory with all stations within this timeframe should work for all operations.

# %% [raw]
# # define the datacenters and channel list
# client_list = ['IRIS', 'NCEDC', 'SCEDC']
# channel_list = 'HH*,BH*,HN*,EH*' # select broadband and high sample rate channels
#
# # time window for the waveform
# starttime = UTCDateTime("2008-01-01")
# endtime = UTCDateTime("2024-01-01")
#
# # create an empty inventory object
# merged_inventory = Inventory()
#
# # Loop through each client (IRIS, NCEDC, SCEDC data centers)
# for client_name in client_list:
#     client = Client(client_name, debug=False, timeout=60)
#     try:
#         inv = client.get_stations(
#             network="*",
#             station="*",
#             location="*",
#             channel=channel_list,
#             starttime=starttime,
#             endtime=endtime,
#             level="channel", # since we spacify the channel, we must use level=channel
#             minlatitude=39,
#             maxlatitude=42,
#             minlongitude=-126,
#             maxlongitude=-122.5, # extend the area by 0.5 deg
#         )
#         merged_inventory.extend(inv.networks)
#
#     except Exception as e:
#         print(f"Error fetching data from {client_name}: {e}")
#
# # write the whole inventory to a file
# merged_inventory.write(f"{station_dir}/00_station_inventory_master.txt", format="STATIONTXT")
# merged_inventory.write(f"{station_dir}/00_station_inventory_master.xml", format="STATIONXML")

# %%
sta_df = pd.read_csv(f"{station_dir}/00_station_inventory_master.txt", delimiter='|')
print(sta_df.shape[0])
sta_df.drop_duplicates(subset=['#Network', 'Station', 'Channel'], inplace=True)
print(sta_df.shape[0])

sta_df.to_csv(f"{station_dir}/00_station_inventory_master_cleaned.txt", index=False, sep='|')
# Out:
# 5145
# 1089

# %% [markdown]
# # 3. Download `.mseed` [and (optional) station_data]
#
# ## Read the inventory files already downloaded
#
# Here I will read the inventory file which contain details about all the stations that recorded a particular earthquake event. \
# From that inventory file I will get all the necessary informations I need to download the seismic data (a numpy timeseries in `.mseed` format). \
# I will also download the metadata for that record in `.xml & .txt` formats.\
#
# This process will use `multiprocessing.Pool.imap_unordered` module for paraller processing of the download.\
# For the code see `./code/my_funcs/get_waveforms_parallel_v3.py` where I defined the download fuction combined with parallel processing. \
# This significantly improves the runtime.

# %% [markdown]
# client_list = ['IRIS', 'NCEDC', 'SCEDC']
# channels_string = 'HH*,BH*,HN*,EH*'                   # by default given to get_waveforms_parallel function
# priority_channels = ['HH*', 'BH*', 'HN*', 'EH*']

# %%
# get a list of mseed files without folder names
mseed_files = [os.path.basename(f) for f in glob.glob(f"{waveform_dir}/*.mseed")]

progress_bar = tqdm(total=len(selected_eq), desc="Downloading events", dynamic_ncols=True)
for i, row in selected_eq.iterrows():
    event_id = row.id

    # check if the event data is already downloaded
    if f"{event_id}.mseed" in mseed_files:
        progress_bar.update(1)
        continue

    event_time = UTCDateTime(pd.to_datetime(row.time))
    starttime = event_time - 30
    endtime = event_time + 120

    xml_file = f"{waveform_dir}/xml/{event_id}_event_inv.xml"
    if os.path.exists(xml_file):
        inv = read_inventory(xml_file)

    else:
        inv = get_station_inventory(starttime, endtime) # client_list, priority_channels are default
        inv.write(xml_file, format="STATIONXML")
        inv = read_inventory(xml_file)
    
    # get the waveforms for the event and save them
    st, inv = get_waveforms_parallel(starttime, endtime, inventory=inv) # client_list, priority_channels are default

    if len(st) > 0:
        st.write(f"{waveform_dir}/{event_id}.mseed", format="MSEED")
        # inv.write(f"{waveform_dir}/{event_id}_event_inv.txt", format="STATIONTXT")
        # remove the inventory file
        os.remove(xml_file)
        print(f"Download complete for {event_id}:len(st)")
        progress_bar.update(1)

    else:
        progress_bar.update(1)
        continue
# Out:
# Downloading events:   0%|          | 0/105 [00:00<?, ?it/s]

# %% [markdown]
# ## testing class function to do the same thing

# %%
from obspy import UTCDateTime
from my_funcs.my_class_funcs import WaveformParallelDownloader
from my_funcs.get_waveforms_parallel_v3 import get_waveforms_parallel, get_station_inventory


evtime = UTCDateTime("2010-01-01")
print(f"Event time : {evtime}")
starttime, endtime = evtime - 30, evtime + 120

wpd = WaveformParallelDownloader(starttime, endtime)
st, inv = wpd.get_waveforms_parallel()

# inv = get_station_inventory(starttime, endtime)
# st, inv = get_waveforms_parallel(starttime, endtime, inventory=inv)

print(inv)
print(len(st))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 from obspy import UTCDateTime
# ----> 2 from my_funcs.my_class_funcs import WaveformParallelDownloader
#       3 from my_funcs.get_waveforms_parallel_v3 import get_waveforms_parallel, get_station_inventory
#       6 evtime = UTCDateTime("2010-01-01")
#
# ModuleNotFoundError: No module named 'my_funcs.my_class_funcs'

# %% [markdown]
# ## (4.1) Use `Phasenet` to pick P and S phases
# An example of phasenet terminal code is: \
# `python phasenet/predict.py --model=model/190703-214543 --data_list=test_data/mseed.csv --data_dir=test_data/mseed --format=mseed --result_dir./phasenet_results --result_fname=phasenet_phasepick_datetime.csv`
#
# ___[[for more details]](https://github.com/AI4EPS/PhaseNet/blob/master/docs/example_batch_prediction.ipynb)

# %% [markdown]
# ### 4.1.1 Make a folder to store the results
# - Also make a list of .mseed files (only filename for phasenet) and put it in a .csv file

# %%
# Make a list of .mseed files into a csv file to input into PhaseNet command line
mseed_list = [os.path.basename(fname) for fname in glob.glob(f"{waveform_dir}/*.mseed")]

# Write the list to a csv file
pd.DataFrame(mseed_list, columns=["fname"]).to_csv(f"{pn_dir}/mseed_list.csv", index=False, header=True)
print(f"Number of mseed files : {len(mseed_list)}")
# Out:
# Number of mseed files : 112

# %% [markdown]
# ### 4.1.2 Make a bash script for running Phasenet

# %%
# Make a script to run PhaseNet 
# *** VVI: every directory is with respect to the location of this notebook ***

script_content = f"""#!/bin/bash

# Change directory into PhaseNet
cd {phasenet_path}

# Activate conda pythoon environment named 'phasenet' [********change miniconda3 to anaconda3 if using Anaconda]
source ~/miniconda3/etc/profile.d/conda.sh # or source ~/anaconda3/etc/profile.d/conda.sh in case of Anaconda
# conda init
conda activate phasenet

# Run Phasenet prediction
python phasenet/predict.py \\
  --model=model/190703-214543 \\
  --data_list={pn_dir}/mseed_list.csv \\
  --data_dir={waveform_dir} \\
  --format=mseed \\
  --amplitude \\
  --batch_size=1 \\
  --sampling_rate=100 \\
  --result_dir={pn_dir} \\
  --result_fname=phasenet_phasepick_3d_grid_new\\
  --min_s_prob=0.95 \\

# Deactivate virtual environment (optional)
# conda deactivate

"""
# --min_p_prob=0.75 \\
# --add_polarity \\
# --plot_figure

# Write the script content to a file
with open(f"{pn_dir}/run_phasenet.sh", "w") as f:
    f.write(script_content)

# Make the script executable
print("Making the script executable...")
os.system(f"chmod +x {pn_dir}/run_phasenet.sh")
# Out:
# Making the script executable...
# 0

# %% [markdown]
# ### 4.1.3 Run Phasenet script:
# If it's already run, it will ask if you want to run again.

# %%
# Run the script
run = input("Do you want to run PhaseNet now? (y/n): ")
if run.lower() == "y":
    print("Running PhaseNet...")
    os.system(f"{pn_dir}/run_phasenet.sh")
else:
    print("PhaseNet already run. Skipping...")
# Out:
# Running PhaseNet...
# 2024-03-31 02:01:28,153 Pred log: /Users/mdarifulislam/Library/CloudStorage/OneDrive-IndianaUniversity/Research/Github/FM2STRESS/FM2STRESS_project/code/../results/phasenet_diting_others/phasenet_files
# 2024-03-31 02:01:28,153 Dataset size: 112
# 2024-03-31 02:01:28,211 Model: depths 5, filters 8, filter size 7x1, pool size: 4x1, dilation rate: 1x1
# 2024-03-31 02:01:28.972117: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2024-03-31 02:01:29.018557: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-03-31 02:01:29,121 restoring model model/190703-214543/model_95.ckpt
# Pred:   0%|          | 0/112 [00:00<?, ?it/s]2024-03-31 02:01:29,622 Resampling 7D.FS01B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,145 Resampling BK.JCC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,188 Resampling 7D.FS01B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,188 Resampling BK.JCC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,189 Resampling 7D.FS01B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,189 Resampling BK.JCC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,190 Resampling 7D.FS02B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,190 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,191 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,191 Resampling 7D.FS02B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,191 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,191 Resampling 7D.FS02B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,192 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,192 Resampling 7D.FS03B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,193 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,193 Resampling 7D.FS03B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,193 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,193 Resampling 7D.FS03B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,194 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,194 Resampling 7D.FS04B..HH1 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,195 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,195 Resampling 7D.FS04B..HH2 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,195 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,195 Resampling 7D.FS04B..HHZ from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,197 Resampling 7D.FS05B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,198 Resampling 7D.FS05B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,199 Resampling 7D.FS05B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,200 Resampling 7D.FS06B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,200 Resampling XQ.ME01.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,201 Resampling 7D.FS06B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,201 Resampling XQ.ME01.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,201 Resampling 7D.FS06B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,202 Resampling XQ.ME01.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,202 Resampling XQ.ME03.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,203 Resampling 7D.FS07B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,203 Resampling XQ.ME03.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,203 Resampling 7D.FS07B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,204 Resampling XQ.ME03.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,204 Resampling XQ.ME08.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,205 Resampling 7D.FS07B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,205 Resampling XQ.ME08.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,205 Resampling XQ.ME08.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,206 Resampling 7D.FS08B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,206 Resampling XQ.ME09.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,207 Resampling XQ.ME09.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,207 Resampling 7D.FS08B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,207 Resampling XQ.ME09.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,208 Resampling 7D.FS08B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,208 Resampling XQ.ME13.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,208 Resampling XQ.ME13.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,209 Resampling 7D.FS09B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,209 Resampling XQ.ME13.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,209 Resampling 7D.FS09B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,210 Resampling XQ.ME27.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,210 Resampling 7D.FS09B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,210 Resampling XQ.ME27.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,211 Resampling 7D.FS10B..HH1 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,211 Resampling XQ.ME27.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,212 Resampling XQ.ME29.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,212 Resampling 7D.FS10B..HH2 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,212 Resampling XQ.ME29.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,213 Resampling 7D.FS10B..HHZ from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,213 Resampling XQ.ME29.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,214 Resampling XQ.ME30.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,214 Resampling 7D.FS11B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,214 Resampling XQ.ME30.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,215 Resampling 7D.FS11B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,215 Resampling XQ.ME30.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,215 Resampling XQ.ME31.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,215 Resampling 7D.FS11B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,216 Resampling XQ.ME31.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,216 Resampling 7D.FS12B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,217 Resampling XQ.ME31.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,217 Resampling 7D.FS12B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,217 Resampling XQ.ME32.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,218 Resampling 7D.FS12B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,218 Resampling XQ.ME32.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,219 Resampling XQ.ME32.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,219 Resampling 7D.FS13B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,219 Resampling XQ.ME33.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,220 Resampling XQ.ME33.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,220 Resampling 7D.FS13B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,221 Resampling XQ.ME33.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,221 Resampling 7D.FS13B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,221 Resampling XQ.ME34.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,222 Resampling XQ.ME34.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,222 Resampling XQ.ME34.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,222 Resampling 7D.FS15B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,223 Resampling XQ.ME35.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,223 Resampling 7D.FS15B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,223 Resampling XQ.ME35.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,224 Resampling XQ.ME35.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,224 Resampling 7D.FS15B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,224 Resampling XQ.ME36.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,225 Resampling XQ.ME36.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,225 Resampling 7D.FS16B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,225 Resampling XQ.ME36.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,225 Resampling 7D.FS16B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,226 Resampling XQ.ME37.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,226 Resampling XQ.ME37.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,226 Resampling 7D.FS16B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,227 Resampling XQ.ME37.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,227 Resampling 7D.FS17B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,228 Resampling XQ.ME38.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,228 Resampling XQ.ME38.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,228 Resampling 7D.FS17B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,229 Resampling XQ.ME38.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,229 Resampling 7D.FS17B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,229 Resampling XQ.ME39.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,230 Resampling XQ.ME39.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,230 Resampling 7D.FS18B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,230 Resampling XQ.ME39.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,231 Resampling XQ.ME42.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,231 Resampling 7D.FS18B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,231 Resampling XQ.ME42.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,232 Resampling 7D.FS18B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,232 Resampling XQ.ME42.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,232 Resampling XQ.ME43.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,233 Resampling 7D.FS19B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,233 Resampling XQ.ME43.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,233 Resampling XQ.ME43.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,234 Resampling 7D.FS19B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,234 Resampling XQ.ME44.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,234 Resampling 7D.FS19B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,235 Resampling XQ.ME44.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,235 Resampling XQ.ME44.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,235 Resampling 7D.FS20B..HH1 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,236 Resampling XQ.ME45.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,236 Resampling 7D.FS20B..HH2 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,236 Resampling XQ.ME45.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,237 Resampling XQ.ME45.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,237 Resampling 7D.FS20B..HHZ from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,238 Resampling XQ.ME46.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,238 Resampling XQ.ME46.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,238 Resampling 7D.G02B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,239 Resampling XQ.ME46.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,239 Resampling 7D.G02B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,239 Resampling XQ.ME47.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,240 Resampling 7D.G02B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,240 Resampling XQ.ME47.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,240 Resampling 7D.G09B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,240 Resampling XQ.ME47.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,241 Resampling XQ.ME49.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,241 Resampling 7D.G09B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,241 Resampling XQ.ME49.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,242 Resampling 7D.G09B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,242 Resampling XQ.ME49.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,242 Resampling XQ.ME50.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,243 Resampling XQ.ME50.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,243 Resampling 7D.G10B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,244 Resampling XQ.ME50.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,244 Resampling 7D.G10B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,244 Resampling 7D.G10B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,245 Resampling XQ.ME52.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,245 Resampling 7D.G17B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,245 Resampling XQ.ME52.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,246 Resampling XQ.ME52.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,246 Resampling 7D.G17B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,246 Resampling XQ.ME54.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,247 Resampling XQ.ME54.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,247 Resampling 7D.G17B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,247 Resampling XQ.ME54.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,248 Resampling XQ.ME63.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,248 Resampling 7D.G19B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,248 Resampling XQ.ME63.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,248 Resampling 7D.G19B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,249 Resampling XQ.ME63.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,249 Resampling 7D.G19B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,252 Resampling 7D.G25B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,258 Resampling 7D.G25B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,263 Resampling 7D.G25B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,267 Resampling 7D.G26B..HH1 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,268 Resampling 7D.G26B..HH2 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,268 Resampling 7D.G26B..HHZ from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,270 Resampling 7D.M13B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,271 Resampling 7D.M13B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,272 Resampling 7D.M13B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,276 Resampling 7D.M14B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,277 Resampling 7D.M14B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,278 Resampling 7D.M14B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,436 Resampling BK.JCC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,436 Resampling BK.JCC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,437 Resampling BK.JCC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,437 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,437 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,438 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,439 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,440 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,441 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,442 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,442 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,443 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:30,451 Resampling TA.M02C..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,453 Resampling TA.M02C..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,453 Resampling TA.M02C..BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,455 Resampling TA.N02D..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,456 Resampling TA.N02D..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,456 Resampling TA.N02D..BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:30,665 Resampling 7D.FS01B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,666 Resampling 7D.FS01B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,667 Resampling 7D.FS01B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,667 Resampling 7D.FS02B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,668 Resampling 7D.FS02B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,669 Resampling 7D.FS02B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,671 Resampling 7D.FS03B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,672 Resampling 7D.FS03B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,673 Resampling 7D.FS03B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,674 Resampling 7D.FS04B..HH1 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,675 Resampling 7D.FS04B..HH2 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,675 Resampling 7D.FS04B..HHZ from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,677 Resampling 7D.FS05B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,677 Resampling 7D.FS05B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,678 Resampling 7D.FS05B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,679 Resampling 7D.FS06B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,680 Resampling 7D.FS06B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,681 Resampling 7D.FS06B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,681 Resampling 7D.FS07B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,682 Resampling 7D.FS07B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,683 Resampling 7D.FS07B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,684 Resampling 7D.FS08B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,685 Resampling 7D.FS08B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,686 Resampling 7D.FS08B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,686 Resampling 7D.FS09B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,687 Resampling 7D.FS09B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,688 Resampling 7D.FS09B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,689 Resampling 7D.FS10B..HH1 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,689 Resampling 7D.FS10B..HH2 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,690 Resampling 7D.FS10B..HHZ from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,691 Resampling 7D.FS11B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,692 Resampling 7D.FS11B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,693 Resampling 7D.FS11B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,694 Resampling 7D.FS12B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,695 Resampling 7D.FS12B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,696 Resampling 7D.FS12B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,696 Resampling 7D.FS13B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,697 Resampling 7D.FS13B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,729 Resampling 7D.FS13B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,731 Resampling 7D.FS15B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,750 Resampling 7D.FS15B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,754 Resampling 7D.FS15B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,761 Resampling 7D.FS16B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,766 Resampling 7D.FS16B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,775 Resampling 7D.FS16B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,779 Resampling 7D.FS17B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,795 Resampling 7D.FS17B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,803 Resampling 7D.FS17B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,814 Resampling 7D.FS18B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,819 Resampling 7D.FS18B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,832 Resampling 7D.FS18B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,847 Resampling 7D.FS19B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,854 Resampling 7D.FS19B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,858 Resampling 7D.FS19B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,867 Resampling 7D.FS20B..HH1 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,884 Resampling 7D.FS20B..HH2 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,890 Resampling 7D.FS20B..HHZ from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,901 Resampling 7D.G02B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,911 Resampling 7D.G02B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,932 Resampling 7D.G02B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,933 Resampling 7D.G09B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,934 Resampling 7D.G09B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,942 Resampling NC.G003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:30,942 Resampling 7D.G09B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,943 Resampling 7D.G10B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,943 Resampling NC.G003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:30,944 Resampling 7D.G10B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,944 Resampling 7D.G10B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,945 Resampling NC.G003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:30,945 Resampling 7D.G17B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,950 Resampling 7D.G17B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,954 Resampling 7D.G17B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,955 Resampling 7D.G18B..HH1 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,968 Resampling 7D.G18B..HH2 from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,982 Resampling 7D.G18B..HHZ from 125.00000762939453 to 100.0 Hz
# 2024-03-31 02:01:30,983 Resampling 7D.G19B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,984 Resampling 7D.G19B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,986 Resampling 7D.G19B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:30,987 Resampling 7D.G25B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,988 Resampling 7D.G25B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,994 Resampling 7D.G25B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:30,996 Resampling 7D.G26B..HH1 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,997 Resampling 7D.G26B..HH2 from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,998 Resampling 7D.G26B..HHZ from 124.99999237060547 to 100.0 Hz
# 2024-03-31 02:01:30,999 Resampling 7D.M13B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:31,000 Resampling 7D.M13B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:31,002 Resampling 7D.M13B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:31,003 Resampling 7D.M14B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,004 Resampling 7D.M14B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,005 Resampling 7D.M14B..BHZ from 50.0 to 100.0 Hz
# Pred:   1%|          | 1/112 [00:01<03:31,  1.91s/it]2024-03-31 02:01:31,387 Resampling 7D.FS02D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,388 Resampling 7D.FS02D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,390 Resampling 7D.FS02D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,391 Resampling 7D.FS04D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,391 Resampling 7D.FS04D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,392 Resampling 7D.FS04D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,393 Resampling 7D.FS06D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,393 Resampling 7D.FS06D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,394 Resampling 7D.FS06D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,395 Resampling 7D.FS07D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,395 Resampling 7D.FS07D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,396 Resampling 7D.FS07D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,396 Resampling 7D.FS08D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,397 Resampling 7D.FS08D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,397 Resampling 7D.FS08D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,398 Resampling 7D.FS09D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,399 Resampling 7D.FS09D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,400 Resampling 7D.FS09D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,400 Resampling 7D.FS10D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,401 Resampling 7D.FS10D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,402 Resampling 7D.FS10D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,402 Resampling 7D.FS13D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,403 Resampling 7D.FS13D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,404 Resampling 7D.FS13D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,404 Resampling 7D.FS16D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,405 Resampling 7D.FS16D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,406 Resampling 7D.FS16D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,407 Resampling 7D.FS41D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,408 Resampling 7D.FS41D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,408 Resampling 7D.FS41D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,410 Resampling 7D.FS44D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,410 Resampling 7D.FS44D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,411 Resampling 7D.FS44D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,412 Resampling 7D.G01D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,413 Resampling 7D.G01D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,413 Resampling 7D.G01D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,414 Resampling 7D.G09D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,415 Resampling 7D.G09D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,416 Resampling 7D.G09D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,416 Resampling 7D.G10D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,417 Resampling 7D.G10D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,418 Resampling 7D.G10D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,418 Resampling 7D.M16D..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,419 Resampling 7D.M16D..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,439 Resampling 7D.M16D..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:31,475 Resampling NC.K003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,481 Resampling NC.K003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,494 Resampling NC.K003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,519 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,524 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,528 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,534 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,537 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,545 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,551 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,553 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,554 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,561 Resampling TA.M02C..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,562 Resampling TA.M02C..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,563 Resampling TA.M02C..BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,568 Resampling TA.N02D..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,569 Resampling TA.N02D..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,570 Resampling TA.N02D..BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,570 Resampling TA.O02D..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,571 Resampling TA.O02D..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,572 Resampling TA.O02D..BHZ from 40.0 to 100.0 Hz
# Pred:   2%|▏         | 2/112 [00:02<01:57,  1.07s/it]2024-03-31 02:01:31,709 Resampling BK.JCC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,710 Resampling BK.JCC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,711 Resampling BK.JCC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,711 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,712 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,713 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,713 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,714 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,714 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,715 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,716 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,717 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:31,722 Resampling XQ.ME01.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,722 Resampling XQ.ME01.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,723 Resampling XQ.ME01.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,723 Resampling XQ.ME03.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,724 Resampling XQ.ME03.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,724 Resampling XQ.ME03.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,725 Resampling XQ.ME04.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,725 Resampling XQ.ME04.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,726 Resampling XQ.ME04.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,726 Resampling XQ.ME07.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,727 Resampling XQ.ME07.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,727 Resampling XQ.ME07.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,728 Resampling XQ.ME08.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,728 Resampling XQ.ME08.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,729 Resampling XQ.ME08.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,729 Resampling XQ.ME09.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,730 Resampling XQ.ME09.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,730 Resampling XQ.ME09.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,731 Resampling XQ.ME13.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,731 Resampling XQ.ME13.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,732 Resampling XQ.ME13.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,732 Resampling XQ.ME27.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,733 Resampling XQ.ME27.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,733 Resampling XQ.ME27.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,733 Resampling XQ.ME29.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,734 Resampling XQ.ME29.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,735 Resampling XQ.ME29.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,735 Resampling XQ.ME30.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,736 Resampling XQ.ME30.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,737 Resampling XQ.ME30.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,737 Resampling XQ.ME31.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,738 Resampling XQ.ME31.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,738 Resampling XQ.ME31.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,739 Resampling XQ.ME32.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,739 Resampling XQ.ME32.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,740 Resampling XQ.ME32.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,740 Resampling XQ.ME33.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,741 Resampling XQ.ME33.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,741 Resampling XQ.ME33.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,742 Resampling XQ.ME34.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,742 Resampling XQ.ME34.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,743 Resampling XQ.ME34.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,743 Resampling XQ.ME35.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,743 Resampling XQ.ME35.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,744 Resampling XQ.ME35.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,745 Resampling XQ.ME36.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,745 Resampling XQ.ME36.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,746 Resampling XQ.ME36.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,746 Resampling XQ.ME37.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,747 Resampling XQ.ME37.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,747 Resampling XQ.ME37.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,748 Resampling XQ.ME38.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,748 Resampling XQ.ME38.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,749 Resampling XQ.ME38.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,749 Resampling XQ.ME39.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,750 Resampling XQ.ME39.01.BHN from 40.0 to 100.0 Hz
# Pred:   3%|▎         | 3/112 [00:02<01:10,  1.54it/s]2024-03-31 02:01:31,764 Resampling XQ.ME39.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,764 Resampling XQ.ME41.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,765 Resampling XQ.ME41.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,765 Resampling XQ.ME41.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,765 Resampling XQ.ME42.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,766 Resampling XQ.ME42.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,766 Resampling XQ.ME42.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,766 Resampling XQ.ME43.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,767 Resampling XQ.ME43.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,767 Resampling XQ.ME43.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,767 Resampling XQ.ME44.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,768 Resampling XQ.ME44.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,768 Resampling XQ.ME44.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,772 Resampling XQ.ME46.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,772 Resampling XQ.ME46.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,774 Resampling XQ.ME46.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,774 Resampling XQ.ME49.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,775 Resampling XQ.ME49.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,775 Resampling XQ.ME49.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,776 Resampling XQ.ME50.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,776 Resampling XQ.ME50.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,777 Resampling XQ.ME50.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,777 Resampling XQ.ME52.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,777 Resampling XQ.ME52.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,778 Resampling XQ.ME52.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,778 Resampling XQ.ME53.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,778 Resampling XQ.ME53.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,779 Resampling XQ.ME53.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,779 Resampling XQ.ME57.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,780 Resampling XQ.ME57.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,780 Resampling XQ.ME57.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:31,868 Resampling NC.G002.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,873 Resampling NC.G002.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,874 Resampling NC.G002.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,876 Resampling NC.G006.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,877 Resampling NC.G006.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,881 Resampling NC.G006.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,882 Resampling NC.G007.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,883 Resampling NC.G007.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,884 Resampling NC.G007.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,885 Resampling NC.K001.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,886 Resampling NC.K001.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,887 Resampling NC.K001.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,887 Resampling NC.K003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,888 Resampling NC.K003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,889 Resampling NC.K003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,893 Resampling NP.1580.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,894 Resampling NP.1580.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,895 Resampling NP.1580.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,896 Resampling NP.1582..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,897 Resampling NP.1582..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,898 Resampling NP.1582..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,898 Resampling NP.1584..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,900 Resampling NP.1584..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,901 Resampling NP.1584..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,902 Resampling NP.1746..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,903 Resampling NP.1746..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,906 Resampling NP.1746..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,909 Resampling WR.NWFF..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,910 Resampling WR.NWFF..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:31,911 Resampling WR.NWFF..HNZ from 200.0 to 100.0 Hz
# Pred:   4%|▎         | 4/112 [00:02<00:53,  2.00it/s]2024-03-31 02:01:32,099 Resampling CE.89101..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,100 Resampling CE.89101..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,101 Resampling CE.89101..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,101 Resampling CE.89255..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,102 Resampling CE.89255..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,102 Resampling CE.89255..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,102 Resampling CE.89462..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,103 Resampling CE.89462..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,104 Resampling CE.89462..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,104 Resampling CE.89509..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,105 Resampling CE.89509..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,106 Resampling CE.89509..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,106 Resampling CE.89781..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,107 Resampling CE.89781..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,108 Resampling CE.89781..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,108 Resampling CE.99640..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,109 Resampling CE.99640..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,109 Resampling CE.99640..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,110 Resampling NC.G002.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,111 Resampling NC.G002.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,111 Resampling NC.G002.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,112 Resampling NC.G003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,113 Resampling NC.G003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,114 Resampling NC.G003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,114 Resampling NC.G006.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,115 Resampling NC.G006.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,116 Resampling NC.G006.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,117 Resampling NC.G007.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,118 Resampling NC.G007.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,119 Resampling NC.G007.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,121 Resampling NC.K001.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,122 Resampling NC.K001.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,123 Resampling NC.K001.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,124 Resampling NC.K002.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,124 Resampling NC.K002.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,125 Resampling NC.K002.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,125 Resampling NC.K003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,126 Resampling NC.K003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,127 Resampling NC.K003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,128 Resampling NC.K004.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,130 Resampling NC.K004.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,131 Resampling NC.K004.01.HNZ from 200.0 to 100.0 Hz
# Pred:   4%|▍         | 5/112 [00:03<00:44,  2.39it/s]2024-03-31 02:01:32,472 Resampling NC.K002.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,473 Resampling NC.K002.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,474 Resampling NC.K002.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,476 Resampling NC.K003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,477 Resampling NC.K003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,478 Resampling NC.K003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,483 Resampling NP.1023..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,484 Resampling NP.1023..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,485 Resampling NP.1023..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,486 Resampling NP.1581..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,487 Resampling NP.1581..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,488 Resampling NP.1581..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,489 Resampling NP.1582..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,490 Resampling NP.1582..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,490 Resampling NP.1582..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,491 Resampling NP.1584..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,492 Resampling NP.1584..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,493 Resampling NP.1584..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,494 Resampling NP.1586..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,495 Resampling NP.1586..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,496 Resampling NP.1586..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,496 Resampling NP.1725..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,497 Resampling NP.1725..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,498 Resampling NP.1725..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,499 Resampling NP.1746..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,500 Resampling NP.1746..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:32,500 Resampling NP.1746..HNZ from 200.0 to 100.0 Hz
# Pred:   5%|▌         | 6/112 [00:03<00:39,  2.70it/s]2024-03-31 02:01:32,598 Resampling BK.JCC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,599 Resampling BK.JCC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,599 Resampling BK.JCC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,600 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,600 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,600 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,601 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,601 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,602 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,602 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,602 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,603 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:32,606 Resampling XQ.ME01.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,606 Resampling XQ.ME01.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,607 Resampling XQ.ME01.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,607 Resampling XQ.ME03.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,607 Resampling XQ.ME03.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,608 Resampling XQ.ME03.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,609 Resampling XQ.ME04.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,610 Resampling XQ.ME04.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,610 Resampling XQ.ME04.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,611 Resampling XQ.ME07.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,614 Resampling XQ.ME07.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,615 Resampling XQ.ME07.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,616 Resampling XQ.ME08.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,617 Resampling XQ.ME08.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,617 Resampling XQ.ME08.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,617 Resampling XQ.ME09.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,618 Resampling XQ.ME09.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,618 Resampling XQ.ME09.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,618 Resampling XQ.ME13.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,619 Resampling XQ.ME13.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,619 Resampling XQ.ME13.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,620 Resampling XQ.ME27.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,620 Resampling XQ.ME27.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,620 Resampling XQ.ME27.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,621 Resampling XQ.ME29.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,621 Resampling XQ.ME29.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,621 Resampling XQ.ME29.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,622 Resampling XQ.ME30.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,622 Resampling XQ.ME30.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,622 Resampling XQ.ME30.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,623 Resampling XQ.ME31.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,623 Resampling XQ.ME31.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,623 Resampling XQ.ME31.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,624 Resampling XQ.ME32.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,624 Resampling XQ.ME32.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,625 Resampling XQ.ME32.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,625 Resampling XQ.ME33.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,625 Resampling XQ.ME33.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,626 Resampling XQ.ME33.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,626 Resampling XQ.ME34.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,627 Resampling XQ.ME34.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,627 Resampling XQ.ME34.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,627 Resampling XQ.ME35.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,628 Resampling XQ.ME35.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,628 Resampling XQ.ME35.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,628 Resampling XQ.ME36.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,629 Resampling XQ.ME36.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,629 Resampling XQ.ME36.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,629 Resampling XQ.ME37.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,630 Resampling XQ.ME37.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,630 Resampling XQ.ME37.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,631 Resampling XQ.ME38.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,631 Resampling XQ.ME38.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,631 Resampling XQ.ME38.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,632 Resampling XQ.ME39.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,632 Resampling XQ.ME39.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,632 Resampling XQ.ME39.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,633 Resampling XQ.ME42.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,633 Resampling XQ.ME42.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,634 Resampling XQ.ME42.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,634 Resampling XQ.ME43.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,634 Resampling XQ.ME43.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,635 Resampling XQ.ME43.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,635 Resampling XQ.ME44.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,635 Resampling XQ.ME44.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,636 Resampling XQ.ME44.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,636 Resampling XQ.ME45.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,636 Resampling XQ.ME45.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,637 Resampling XQ.ME45.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,637 Resampling XQ.ME46.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,637 Resampling XQ.ME46.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,638 Resampling XQ.ME46.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,638 Resampling XQ.ME47.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,638 Resampling XQ.ME47.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,639 Resampling XQ.ME47.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,639 Resampling XQ.ME49.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,639 Resampling XQ.ME49.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,640 Resampling XQ.ME49.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,640 Resampling XQ.ME50.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,640 Resampling XQ.ME50.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,641 Resampling XQ.ME50.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,642 Resampling XQ.ME52.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,643 Resampling XQ.ME52.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,643 Resampling XQ.ME52.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,643 Resampling XQ.ME53.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,644 Resampling XQ.ME53.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:32,644 Resampling XQ.ME53.01.BHZ from 40.0 to 100.0 Hz
# ...
# 2024-03-31 02:01:55,259 Resampling 7D.M13B..HH1 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:55,260 Resampling 7D.M13B..HH2 from 125.0 to 100.0 Hz
# 2024-03-31 02:01:55,260 Resampling 7D.M13B..HHZ from 125.0 to 100.0 Hz
# 2024-03-31 02:01:55,261 Resampling 7D.M14B..BH1 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:55,261 Resampling 7D.M14B..BH2 from 50.0 to 100.0 Hz
# 2024-03-31 02:01:55,261 Resampling 7D.M14B..BHZ from 50.0 to 100.0 Hz
# 2024-03-31 02:01:55,263 Resampling NC.K002.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,264 Resampling NC.K002.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,265 Resampling NC.K002.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,267 Resampling NC.K003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,267 Resampling NC.K003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,268 Resampling NC.K003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,269 Resampling NC.K004.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,270 Resampling NC.K004.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,270 Resampling NC.K004.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,279 Resampling TA.O02D..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:55,280 Resampling TA.O02D..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:55,280 Resampling TA.O02D..BHZ from 40.0 to 100.0 Hz
# Pred:  89%|████████▉ | 100/112 [00:26<00:02,  4.30it/s]2024-03-31 02:01:55,690 Resampling NC.G003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,690 Resampling NC.G003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,692 Resampling NC.G003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,699 Resampling NP.1580.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,701 Resampling NP.1580.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:55,702 Resampling NP.1580.01.HNZ from 200.0 to 100.0 Hz
# Pred:  90%|█████████ | 101/112 [00:26<00:03,  3.59it/s]2024-03-31 02:01:55,873 Resampling BK.JCC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,873 Resampling BK.JCC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,874 Resampling BK.JCC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,874 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,875 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,875 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,876 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,876 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,876 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,877 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,877 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,877 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,883 Resampling TA.M02C..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:55,884 Resampling TA.M02C..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:55,885 Resampling TA.M02C..BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:55,885 Resampling TA.N02D..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:55,888 Resampling TA.N02D..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:55,889 Resampling TA.N02D..BHZ from 40.0 to 100.0 Hz
# Pred:  91%|█████████ | 102/112 [00:26<00:02,  4.41it/s]2024-03-31 02:01:55,979 Resampling BK.JCC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,980 Resampling BK.JCC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,981 Resampling BK.JCC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,981 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,982 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,982 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,982 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,983 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,983 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,983 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,984 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:55,984 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# Pred:  92%|█████████▏| 103/112 [00:26<00:01,  4.97it/s]2024-03-31 02:01:56,130 Resampling NC.G002.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,131 Resampling NC.G002.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,132 Resampling NC.G002.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,133 Resampling NC.G006.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,134 Resampling NC.G006.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,135 Resampling NC.G006.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,135 Resampling NC.G007.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,136 Resampling NC.G007.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,137 Resampling NC.G007.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,139 Resampling NC.K001.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,139 Resampling NC.K001.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,140 Resampling NC.K001.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,141 Resampling NC.K003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,142 Resampling NC.K003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,143 Resampling NC.K003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,148 Resampling NP.1580.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,149 Resampling NP.1580.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,150 Resampling NP.1580.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,150 Resampling NP.1582..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,151 Resampling NP.1582..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,153 Resampling NP.1582..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,154 Resampling NP.1584..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,154 Resampling NP.1584..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,155 Resampling NP.1584..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,157 Resampling NP.1746..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,158 Resampling NP.1746..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,159 Resampling NP.1746..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,162 Resampling WR.NWFF..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,163 Resampling WR.NWFF..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,164 Resampling WR.NWFF..HNZ from 200.0 to 100.0 Hz
# Pred:  93%|█████████▎| 104/112 [00:27<00:01,  5.05it/s]2024-03-31 02:01:56,294 Resampling BK.JCC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,295 Resampling BK.JCC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,295 Resampling BK.JCC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,295 Resampling BK.WDC..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,296 Resampling BK.WDC..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,297 Resampling BK.WDC..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,297 Resampling BK.YBH..HH1 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,298 Resampling BK.YBH..HH2 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,298 Resampling BK.YBH..HH3 from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,299 Resampling BK.YBH..HHE from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,299 Resampling BK.YBH..HHN from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,300 Resampling BK.YBH..HHZ from 80.0 to 100.0 Hz
# 2024-03-31 02:01:56,302 Resampling XQ.ME01.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,303 Resampling XQ.ME01.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,303 Resampling XQ.ME01.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,304 Resampling XQ.ME03.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,304 Resampling XQ.ME03.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,305 Resampling XQ.ME03.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,305 Resampling XQ.ME04.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,305 Resampling XQ.ME04.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,306 Resampling XQ.ME04.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,306 Resampling XQ.ME08.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,306 Resampling XQ.ME08.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,307 Resampling XQ.ME08.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,307 Resampling XQ.ME09.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,307 Resampling XQ.ME09.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,308 Resampling XQ.ME09.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,309 Resampling XQ.ME13.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,310 Resampling XQ.ME13.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,310 Resampling XQ.ME13.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,310 Resampling XQ.ME27.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,311 Resampling XQ.ME27.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,311 Resampling XQ.ME27.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,311 Resampling XQ.ME29.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,312 Resampling XQ.ME29.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,312 Resampling XQ.ME29.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,312 Resampling XQ.ME30.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,313 Resampling XQ.ME30.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,313 Resampling XQ.ME30.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,314 Resampling XQ.ME31.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,314 Resampling XQ.ME31.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,314 Resampling XQ.ME31.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,319 Resampling XQ.ME32.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,319 Resampling XQ.ME32.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,320 Resampling XQ.ME32.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,320 Resampling XQ.ME33.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,321 Resampling XQ.ME33.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,321 Resampling XQ.ME33.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,321 Resampling XQ.ME34.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,322 Resampling XQ.ME34.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,322 Resampling XQ.ME34.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,322 Resampling XQ.ME35.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,323 Resampling XQ.ME35.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,323 Resampling XQ.ME35.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,323 Resampling XQ.ME36.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,324 Resampling XQ.ME36.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,324 Resampling XQ.ME36.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,325 Resampling XQ.ME37.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,325 Resampling XQ.ME37.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,325 Resampling XQ.ME37.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,326 Resampling XQ.ME38.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,326 Resampling XQ.ME38.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,326 Resampling XQ.ME38.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,327 Resampling XQ.ME39.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,327 Resampling XQ.ME39.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,327 Resampling XQ.ME39.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,328 Resampling XQ.ME42.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,328 Resampling XQ.ME42.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,330 Resampling XQ.ME42.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,330 Resampling XQ.ME43.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,331 Resampling XQ.ME43.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,331 Resampling XQ.ME43.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,332 Resampling XQ.ME44.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,332 Resampling XQ.ME44.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,332 Resampling XQ.ME44.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,333 Resampling XQ.ME45.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,333 Resampling XQ.ME45.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,333 Resampling XQ.ME45.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,334 Resampling XQ.ME46.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,334 Resampling XQ.ME46.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,334 Resampling XQ.ME46.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,335 Resampling XQ.ME47.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,335 Resampling XQ.ME47.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,335 Resampling XQ.ME47.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,336 Resampling XQ.ME49.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,336 Resampling XQ.ME49.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,336 Resampling XQ.ME49.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,337 Resampling XQ.ME50.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,337 Resampling XQ.ME50.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,337 Resampling XQ.ME50.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,338 Resampling XQ.ME52.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,339 Resampling XQ.ME52.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,340 Resampling XQ.ME52.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,340 Resampling XQ.ME54.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,340 Resampling XQ.ME54.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,341 Resampling XQ.ME54.01.BHZ from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,341 Resampling XQ.ME63.01.BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,341 Resampling XQ.ME63.01.BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,342 Resampling XQ.ME63.01.BHZ from 40.0 to 100.0 Hz
# Pred:  94%|█████████▍| 105/112 [00:27<00:01,  4.81it/s]2024-03-31 02:01:56,550 Resampling NC.G002.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,551 Resampling NC.G002.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,551 Resampling NC.G002.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,552 Resampling NC.G006.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,553 Resampling NC.G006.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,554 Resampling NC.G006.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,554 Resampling NC.G007.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,555 Resampling NC.G007.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,556 Resampling NC.G007.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,558 Resampling NC.K001.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,559 Resampling NC.K001.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,559 Resampling NC.K001.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,560 Resampling NC.K003.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,561 Resampling NC.K003.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,562 Resampling NC.K003.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,567 Resampling NP.1580.01.HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,568 Resampling NP.1580.01.HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,569 Resampling NP.1580.01.HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,569 Resampling NP.1582..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,570 Resampling NP.1582..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,570 Resampling NP.1582..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,571 Resampling NP.1584..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,572 Resampling NP.1584..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,572 Resampling NP.1584..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,573 Resampling NP.1746..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,574 Resampling NP.1746..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,574 Resampling NP.1746..HNZ from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,576 Resampling WR.NWFF..HNE from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,577 Resampling WR.NWFF..HNN from 200.0 to 100.0 Hz
# 2024-03-31 02:01:56,578 Resampling WR.NWFF..HNZ from 200.0 to 100.0 Hz
# Pred:  95%|█████████▍| 106/112 [00:27<00:01,  4.77it/s]2024-03-31 02:01:56,879 Resampling TA.O02D..BHE from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,879 Resampling TA.O02D..BHN from 40.0 to 100.0 Hz
# 2024-03-31 02:01:56,880 Resampling TA.O02D..BHZ from 40.0 to 100.0 Hz
# Pred: 100%|██████████| 112/112 [00:28<00:00,  3.93it/s]
# Done with 6513 P-picks and 33 S-picks

# %% [markdown]
# **important**
# on mac m1, there is no CUDA support (NVIDIA), so in EQNet-master/predict.py (most probably) set `torch.device('cpu') and search args.device and in each function add `args.device = 'cpy'` to use cpu focefully instead of GPU

# %% [markdown]
# # 5. Determine polarity using DitingMotion

# %%
diting_model_dir = "./DiTing_model/models/DiTingMotionJul.hdf5"
phasnet_picks = f"{pn_dir}/phasenet_phasepick_3d_grid_new.csv"
phasenet_df = pd.read_csv(phasnet_picks, parse_dates=["begin_time", "phase_time"])
phasenet_df = phasenet_df[(phasenet_df.phase_type == "P") & (phasenet_df.phase_score >= 0.0)] # filter out only P picks

# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppress TensorFlow logging
diting_model = tf.keras.models.load_model(diting_model_dir, compile=False)

# %%
# from my_funcs.my_class_funcs import DitingMotionPicker
# %reload_ext autoreload
# %autoreload 2

# dmp = DitingMotionPicker()
# pol_pick_df1 = dmp.assign_polarity(mseed_list=mseed_list[0:5],
#                                 phaesnet_picks_df=phasenet_df,
#                                 motion_model=diting_model,
#                                 waveform_dir=waveform_dir,
#                                 )
# # 
# # pol_pick_df1.to_csv(f"{pn_dir}/diting_phasenet_3d_grid.csv", index=False)
# pol_pick_df1.head()

# %% [markdown]
# ## Use parallelized function in my custom clases

# %%
from classes_functions.my_class_funcs import DitingMotionPicker
# %reload_ext autoreload
run = input("Do you want to run DiTing Motion Picker now? (y/n): ")
if run.lower() == "y":
    dmp = DitingMotionPicker(mseed_list, waveform_dir, phasenet_df, diting_model)
    pol_pick_df = dmp.assign_polarity_parallel()

    print(pol_pick_df.shape)
    pol_pick_df.to_csv(f"{pn_dir}/diting_phasenet_3d_grid_low_con.csv", index=False)
# Out:
# Polarity Detection:   0%|          | 0/112 [00:00<?, ?it/s]
# (6513, 11)

# %% [markdown]
# ### (OPTIONAL): I should put nan values for diting polarity if PhaseNet phase_score is not >=0.8
# That way I will have the picked stations in the dataframe but have good quality polarity.
# Because it was giving me problem when merging with pyrocko manual picks. There i have to add station rows for a event later in complecated forloop.

# %%
pol_pick_df = pd.read_csv(f"{pn_dir}/diting_phasenet_3d_grid_low_con.csv", parse_dates=["begin_time", "phase_time"])
pol_pick_lowcon_df = pol_pick_df.copy()

# if phase_score < 0.8, then replace the diting_polarity with 'L'
pol_pick_df.loc[pol_pick_df.phase_score < 0.8, 'diting_polarity'] = 'L'

# if diting_polarity or diting_sharpness is <class 'NoneType'>, then replace with 'x'
# pol_pick_df.loc[pol_pick_df.diting_polarity.isna(), 'diting_polarity'] = 'None'
# pol_pick_df.loc[pol_pick_df.diting_sharpness.isna(), 'diting_sharpness'] = 'None'

# print(type(pol_pick_df.loc[26, 'diting_polarity']))
pol_pick_df.to_csv(f"{pn_dir}/diting_phasenet_3d_grid.csv", index=False)
print(f"{pn_dir}/diting_phasenet_3d_grid.csv")
# Out:
# /Users/mdarifulislam/Library/CloudStorage/OneDrive-IndianaUniversity/Research/Github/FM2STRESS/FM2STRESS_project/code/../results/phasenet_diting_others/phasenet_files/diting_phasenet_3d_grid.csv

# %% [markdown]
# # 6. Convert PyRocko picks into phasenet format csv file
# N.B. See next notebook for now

# %%
ppick_file = f'{pn_dir}/diting_phasenet_3d_grid.csv' 
pyrocko_markers = f'{project_dir}/results/phasenet_diting_others/00_47_all_picks_PN_PR_DT.txt'

outpath_allpick = f'{pn_dir}/ALL_PICKS_POL.csv'

from classes_functions.my_class_funcs import MyFileConverter
# %reload_ext autoreload
# %autoreload 2

mfc = MyFileConverter()
all_picks_df = mfc.convert_pyrocko_picks_to_phasenet2(pyrocko_markers, ppick_file)

all_picks_df.sort_values(by='file_name', inplace=True) # sort by file_name
all_picks_df.reset_index(drop=True, inplace=True) # reset index
all_picks_df.to_csv(outpath_allpick, index=False) 
print(outpath_allpick)
# Out:
# Skipping 7D.FS10B..HH - nc71919066.mseed - P - None
# Skipping NC.K002.01.HN - nc71919066.mseed - P - None
# Skipping 7D.FS41D..BH - nc72239881.mseed - P - None
# Skipping NC.KRP..HH - nc72731930.mseed - P - None
# Added 42 new rows to the dataframe.
# Skipped 4 rows.
# /Users/mdarifulislam/Library/CloudStorage/OneDrive-IndianaUniversity/Research/Github/FM2STRESS/FM2STRESS_project/code/../results/phasenet_diting_others/phasenet_files/ALL_PICKS_POL.csv

# %% [markdown]
# ## Distribution

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 6))

pol_pick_lowcon_df.diting_polarity.value_counts().plot(kind='bar', ax=ax[0], grid=True)
all_picks_df.diting_polarity.value_counts().plot(kind='bar', ax=ax[1], grid=True)
all_picks_df.pyrocko_polarity.value_counts().plot(kind='bar', ax=ax[2], grid=True)

ax[0].set_title("DiTing Polarity (Low Confidence)")
ax[1].set_title("DiTing Polarity (High Confidence)")
ax[2].set_title("Pyrocko Polarity")

# same y-axis scale for all plots
ymin, ymax = 0, 3000
for i in range(3):
    ax[i].set_ylim(ymin, ymax)

plt.tight_layout()
plt.show()

# %% [markdown]
# # xx. Plot the PyRocko manual picks and phasenet+DiTingMotion picks on the seismic data

# %%
def get_sta_dist(folder_station, eid, elat, elon):
    """
    For plotting
    folder_station: folder containing station information (such as ../data/eq_data/event_id/)
    input: event id, event latitude, event longitude
    output: dataframe containing
        - station names
        - distances
        - station latitude
        - station longitude
    """
    from geopy.distance import geodesic

    sta_file = f"{folder_station}/{eid}_event_inv.txt"

    # read station inventory file
    sta_df = pd.read_csv(sta_file, 
                        sep='|', 
                        header=0,
                        usecols=[1, 4, 5]) # Station|Latitude|Longitude    
    # keep only unique station names
    sta_df = sta_df.drop_duplicates(subset=['Station'])

    stanames, slat, slon = sta_df['Station'].values, sta_df['Latitude'].values, sta_df['Longitude'].values
    distances = []
    for i in range(0, len(sta_df)):
        distances.append(geodesic((elat, elon), (slat[i], slon[i])).km)
    distances = np.array(distances)

    # make a dataframe to return 
    df = pd.DataFrame()
    df['stanames'] = stanames
    df['distances'] = distances
    df['slat'] = slat
    df['slon'] = slon
    df = df.sort_values(by='distances', ascending=True).reset_index(drop=True)
    return df



def get_phasenet_phasepicks(phasenet_file, eid):
    """
    Get the phase picks from the PhaseNet output file for a given event id
    """

    df = pd.read_csv(phasenet_file, header=0, parse_dates=['phase_time'])
    subdf = df.loc[df.file_name.str.split('.').str[0]==eid,:]
    subdf.loc[:, 'station_id'] = subdf.station_id.str.split('.').str[1]

    subdf2 = subdf.loc[:, ['station_id', 'phase_time', 'phase_type']]
    subdf2.phase_time = pd.to_datetime(subdf2.phase_time)

    return subdf2

# %%
mseed = f'{data_path}/{mseed_list[0]}'

row = selected_eq.loc[selected_eq.id == mseed_list[0].split('.')[0]]
eid, elat, elon, emag, edepth = row.id.values[0], row.latitude.values[0], row.longitude.values[0], row.mag.values[0], row.depth.values[0]
t_origin = UTCDateTime(pd.to_datetime(row.time.values[0]))

sta_df = get_sta_dist(f"{data_path}", eid, elat, elon)
stnames, stdist, slat, slon = sta_df['stanames'].values, sta_df['distances'].values, sta_df['slat'].values, sta_df['slon'].values
phase_picks = get_phasenet_phasepicks(f"{data_path}/phasenet_files/phasenet_phasepick_datetime.csv", eid)

# Read the mseed file
st = read(mseed)

# Plot the waveform
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(1,1,1)

for i in range(len(stnames)):
    sta = str(stnames[i])
    temp_st = st.select(station=sta)
    temp_st2 = temp_st.select(component='Z')

    tr = temp_st[0]
    tr.detrend('demean')
    tr.filter('bandpass', freqmin=2, freqmax=20)
    tr.taper(0.05)
    tr.data = tr.data/np.max(tr.data)

    # time array
    t = (tr.stats.starttime-t_origin) + np.arange(0, tr.stats.npts)/tr.stats.sampling_rate

    # plot waveform, lw is linewidth
    ax.plot(t, tr.data+i, lw=0.5)

    # plot P and S arrivals
    filtered_data = phase_picks.loc[phase_picks.station_id == sta]  # Filter for the station ID once

    for index, row in filtered_data.iterrows():
        phase_type = row['phase_type']
        phase_time_temp = UTCDateTime(row['phase_time'])
        dt = phase_time_temp - t_origin

        if phase_type == 'P':
            ax.plot([dt, dt], [i - 0.8, i + 0.8], 'k', label='P-arrival' if i == 0 else None)
        elif phase_type == 'S':
            ax.plot([dt, dt], [i - 0.8, i + 0.8], 'b', label='S-arrival' if i == 0 else None)

    # plot station name
    ax.text(0, i, sta)  

ax.legend(loc='upper right')
ax.set_xlim([-5, 60])
ax.set_xlabel('Time [s]')
ax.set_ylabel('Distance from epicenter [km]')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mseed = f'{data_path}/{mseed_list[0]}'
#       3 row = selected_eq.loc[selected_eq.id == mseed_list[0].split('.')[0]]
#       4 eid, elat, elon, emag, edepth = row.id.values[0], row.latitude.values[0], row.longitude.values[0], row.mag.values[0], row.depth.values[0]
#
# NameError: name 'data_path' is not defined
