# %% [markdown]
# # Earthquake Data Download
# This notebook will used selected events in step 2.
# Then download the `mseed` file and associated `inventory (txt)` files for each events for events in the study area.
# Since this is a fairly small study area start time of 30s before the event time will be enough for the most distant ones as well.
#
# ---

# %% [markdown]
# ### Import all necessary libraries here, this will make things easier later

# %%
import os
import time
from tqdm.auto import tqdm
import glob

import pandas as pd
import numpy as np
from obspy.clients.fdsn import Client
from obspy import UTCDateTime, read_inventory, Inventory, read, Stream
import matplotlib.pyplot as plt

# %% [markdown]
# # Setup all directories

# %%
# set up the project directory
project_dir = f"{os.getcwd()}/../"
data_dir = os.path.join(project_dir, "data/eq_data") # include data folders for eq catalogs, waveforms, and station catalogs
catalog_dir = os.path.join(data_dir, "1_eq_catalogs") # all eq catalogs: orig and edited
waveform_dir = os.path.join(data_dir, "2_waveforms") # mseed files
station_dir = os.path.join(data_dir, "3_station_catalogs") # station xml files

selected_eq = f'{catalog_dir}/usgs_aboveslab_3D_grid_coarse.csv'
selected_eq_df = pd.read_csv(selected_eq, parse_dates=['time'])

# %% [markdown]
# ## 2.1 Make a master inventory file
# As we select events from 2008 to end of 2023, a master station inventory with all stations within this timeframe should work for all operations.

# %%
# define the datacenters and channel list
client_list = ['IRIS', 'NCEDC', 'SCEDC']
channel_list = ['HHZ', 'BHZ', 'HNZ', 'EHZ', 'SHZ', 'DPZ', 'SLZ', 'CNZ', 'HN3', 'HH3', 'ENZ']
channel_list = ','.join(channel_list)

# time window for the waveform
starttime = UTCDateTime("2008-01-01")
endtime = UTCDateTime("2024-01-01")

# boundary 
minlat = 39.75 - 2
maxlat = 41.5 + 2
minlon = -125.5 - 2
maxlon = -123 + 3

# create an empty inventory object
merged_inventory = Inventory()

# Loop through each client (IRIS, NCEDC, SCEDC data centers)
for client_name in client_list:
    client = Client(client_name, debug=False, timeout=60)
    try:
        inv = client.get_stations(
            network="*",
            station="*",
            location="*",
            channel=channel_list,
            starttime=starttime,
            endtime=endtime,
            level="channel", # since we spacify the channel, we must use level=channel
            minlatitude=minlat,
            maxlatitude=maxlat,
            minlongitude=minlon,
            maxlongitude=maxlon,
        )
        merged_inventory.extend(inv.networks)
        
    except Exception as e:
        print(f"Error fetching data from {client_name}: {e}")    

# cleanup before writing
merged_inventory.write(f"temp_inv.txt", format="STATIONTXT")
inv = pd.read_csv("temp_inv.txt", delimiter='|').drop_duplicates(
    subset=['#Network', 'Station', 'Location', 'Channel'])
inv.to_csv('temp_inv.txt', sep='|', index=False)
inv = read_inventory('temp_inv.txt', format='STATIONTXT')
inv.write(f"{station_dir}/00_station_inventory_master.xml", format="STATIONXML")
inv.write(f"{station_dir}/00_station_inventory_master.txt", format="STATIONTXT")

# %%
print(sta_df.shape[0])
sta_df
print(sta_df.shape[0])

sta_df.to_csv(f"{station_dir}/00_station_inventory_master_921.txt", index=False, sep='|')
# Out:
# 23520
# 6466

# %% [markdown]
# # 3. Download `.mseed` [and (optional) station_data]
#
# ## Read the inventory files already downloaded
#
# Here I will read the inventory file which contain details about all the stations that recorded a particular earthquake event. \
# From that inventory file I will get all the necessary informations I need to download the seismic data (a numpy timeseries in `.mseed` format). \
# I will also download the metadata for that record in `.xml & .txt` formats.\
#
# This process will use `multiprocessing.Pool.imap_unordered` module for paraller processing of the download.\
# For the code see `./code/my_funcs/get_waveforms_parallel_v3.py` where I defined the download fuction combined with parallel processing. \
# This significantly improves the runtime.

# %% [markdown]
# client_list = ['IRIS', 'NCEDC', 'SCEDC']
# channels_string = 'HH*,BH*,HN*,EH*'                   # by default given to get_waveforms_parallel function
# priority_channels = ['HH*', 'BH*', 'HN*', 'EH*']

# %% [raw]
# from classes_functions.get_waveforms_parallel_v3 import get_waveforms_parallel, get_station_inventory
# %reload_ext autoreload
# %autoreload 2
#
# # get a list of mseed files without folder names
# mseed_files = [os.path.basename(f) for f in glob.glob(f"{waveform_dir}/*.mseed")]
#
# client_list = ['IRIS', 'NCEDC', 'SCEDC']
# priority_channels_list = ['HHZ', 'BHZ', 'HNZ', 'EHZ']
#
# barlen = len(selected_eq_df) - len(mseed_files)
# progress_bar = tqdm(total=barlen, desc="Downloading events", dynamic_ncols=True)
#
# # loop through the selected events and download the waveforms
# for i, row in selected_eq_df.iterrows():
#     event_id = row.id
#
#     # check if the event data is already downloaded
#     if f"{event_id}.mseed" in mseed_files:
#         # print(f"Event {event_id} already downloaded")
#         progress_bar.update(1)
#         continue
#
#     event_time = UTCDateTime(pd.to_datetime(row.time))
#     starttime = event_time - 30
#     endtime = event_time + 120
#
#     xml_file = f"{waveform_dir}/xml/{event_id}_event_inv.xml"
#     if os.path.exists(xml_file):
#         inv = read_inventory(xml_file)
#
#     if len(inv) == 0:
#         t1 = time.time()
#         inv = get_station_inventory(
#             starttime, endtime,
#             client_list=client_list,
#             priority_channels_list=priority_channels_list,
#         )
#         inv.write(xml_file, format="STATIONXML")
#         inv = read_inventory(xml_file)
#         print(f"Inventory file created for {event_id}, length {len(inv)}. Took {time.time()-t1:.2f} seconds")
#
#     # # # get the waveforms for the event and save them
#     # t1 = time.time()
#     # print(f"Downloading waveforms for {event_id}")
#     # st, evinv = get_waveforms_parallel(
#     #     starttime, endtime, inventory=inv,
#     #     client_list = client_list,
#     #     priority_channels_list = priority_channels_list,
#     # )
#
#     # print(f"Downloaded {len(st)} waveforms")
#
#     # if len(st) > 0:
#     #     st.write(f"{waveform_dir}/{event_id}.mseed", format="MSEED")
#     #     # evinv.write(f"{waveform_dir}/{event_id}_event_inv.txt", format="STATIONTXT")
#     #     print(f"Download complete for {i, event_id}:len(st). Took {time.time()-t1:.2f} seconds")
#     #     progress_bar.update(1)
#
#     # else:
#     #     progress_bar.update(1)
#     #     print(f"No waveforms downloaded for {event_id}")
#     #     continue
#
# # remove the inventory file
# # os.remove(xml_file)
#
# # progress_bar.close()

# %% [markdown]
#  ### Class function [Latest (after v3)]

# %%
from classes_functions.get_WF_parallel_class import GetWFInvParallel
# %reload_ext autoreload
# %autoreload 2

os.makedirs(f"{waveform_dir}/inv_txt", exist_ok=True)
os.makedirs(f"{waveform_dir}/xml", exist_ok=True)

# get a list of mseed files without folder names
mseed_files = [os.path.basename(f) for f in glob.glob(f"{waveform_dir}/*.mseed")]

client_list = ['IRIS', 'NCEDC', 'SCEDC']
priority_channels_list = ['HHZ', 'BHZ', 'HNZ', 'EHZ']

barlen = len(selected_eq_df)# - len(mseed_files)
progress_bar = tqdm(total=barlen, desc="Downloading events", dynamic_ncols=True)

# loop through the selected events and download the waveforms
for i, row in selected_eq_df.iterrows():
    event_id = row.id

    # check if the event data is already downloaded
    if os.path.exists(f"{waveform_dir}/{event_id}.mseed"):
        print(f"Event {event_id} already downloaded")
        progress_bar.update(1)
        continue

    event_time = UTCDateTime(pd.to_datetime(row.time))
    starttime = event_time - 30
    endtime = event_time + 120

    # initialize the class
    gwfip  = GetWFInvParallel(starttime, endtime)

    # inventory file
    inv_xml_file = f"{waveform_dir}/xml/{event_id}_event_inv.xml"
    inv_txt_file = f"{waveform_dir}/inv_txt/{event_id}_event_inv.txt"

    # check existing 
    if os.path.exists(inv_xml_file):
        print('Using existing inventory')
        inv = read_inventory(inv_xml_file, format="STATIONXML")
    
    elif not os.path.exists(inv_xml_file) or len(inv) == 0:
        invdf = gwfip.get_inventory(
            radial_search=True,
            event_lat=row.latitude,
            event_lon=row.longitude,
        )
        # Drop duplicate stations, keep '**Z' channels [sorted by net-sta-cha]
        invdf = invdf.drop_duplicates(subset=['#Network', 'Station'], keep='last')
        invdf.to_csv(inv_txt_file, sep='|', index=False)
        inv = read_inventory(inv_txt_file, format="STATIONTXT")
        inv.write(inv_xml_file, format="STATIONXML")


    # get the waveforms for the event and save them
    t1 = time.time()

    # get the waveforms
    st, evinv = gwfip.get_waveforms_parallel(inv_txt_file)

    # save the waveforms if valid
    if len(st) > 0:
        st.write(f"{waveform_dir}/{event_id}.mseed", format="MSEED")
        print(f"Download complete for {i, event_id}:{len(st)}. Took {time.time()-t1:.2f} seconds")
        progress_bar.update(1)
        # break

    else:
        progress_bar.update(1)
        print(f"No waveforms downloaded for {event_id}")
        continue
        # break
# Out:
# Downloading events:   0%|          | 0/921 [00:00<?, ?it/s]
# Event nc71356495 already downloaded
# Event nc72075736 already downloaded
# Event nc71648526 already downloaded
# Event nc72182326 already downloaded
# Event nc72182151 already downloaded
# Event nc71977175 already downloaded
# Event nc71759805 already downloaded
# Event nc71755770 already downloaded
# Event nc72090976 already downloaded
# Event nc72082251 already downloaded
# Event nc72182136 already downloaded
# Event nc72807961 already downloaded
# Event nc72930205 already downloaded
# Event nc73397316 already downloaded
# Event nc71810766 already downloaded
# Event nc72239881 already downloaded
# Event nc71166021 already downloaded
# Event nc71180461 already downloaded
# Event nc72538480 already downloaded
# Event nc71102321 already downloaded
# Event nc51214355 already downloaded
# Event nc71118291 already downloaded
# Event nc71163066 already downloaded
# Event nc71592110 already downloaded
# Event nc72729510 already downloaded
# Event nc71157011 already downloaded
# Event nc72310146 already downloaded
# Event nc73794901 already downloaded
# Event nc71649331 already downloaded
# Event nc71273430 already downloaded
# Event nc73610261 already downloaded
# Event nc51208596 already downloaded
# Event nc40221268 already downloaded
# Event nc71546480 already downloaded
# Event nc71512100 already downloaded
# Event nc71214841 already downloaded
# Event nc71544046 already downloaded
# Event nc71249101 already downloaded
# Event nc71415920 already downloaded
# Event nc40221758 already downloaded
# Event nc72337840 already downloaded
# Event nc71378821 already downloaded
# Event nc71376126 already downloaded
# Event nc71679711 already downloaded
# Event nc71126035 already downloaded
# Event nc71795061 already downloaded
# Event nc71341231 already downloaded
# Event nc71986471 already downloaded
# Event nc71940250 already downloaded
# Event nc72086051 already downloaded
# Event nc73139131 already downloaded
# Event nc73139191 already downloaded
# Event nc73139201 already downloaded
# Event nc73139181 already downloaded
# Event nc73139176 already downloaded
# Event nc73139166 already downloaded
# Event nc73212201 already downloaded
# Event nc72122060 already downloaded
# Event nc73380055 already downloaded
# Event nc71837896 already downloaded
# Event nc40219601 already downloaded
# Event nc73139206 already downloaded
# Event nc73784121 already downloaded
# Event nc71122560 already downloaded
# Event nc40218508 already downloaded
# Event nc71984346 already downloaded
# Event nc40237942 already downloaded
# Event nc73139226 already downloaded
# Event nc73139351 already downloaded
# Event nc73139331 already downloaded
# Event nc71984396 already downloaded
# Event nc73149971 already downloaded
# Event nc73144951 already downloaded
# Event nc73144391 already downloaded
# Event nc73140715 already downloaded
# Event nc72187616 already downloaded
# Event nc73139515 already downloaded
# Event nc73139321 already downloaded
# Event nc73138650 already downloaded
# Event nc73138275 already downloaded
# Event nc73139456 already downloaded
# Event nc73139411 already downloaded
# Event nc73139371 already downloaded
# Event nc73139366 already downloaded
# Event nc73139341 already downloaded
# Event nc73139336 already downloaded
# Event nc73138325 already downloaded
# Event nc73802800 already downloaded
# Event nc72122000 already downloaded
# Event nc72132331 already downloaded
# Event nc72121430 already downloaded
# Event nc71203430 already downloaded
# Event nc73151961 already downloaded
# Event nc51222068 already downloaded
# Event nc73642185 already downloaded
# Event nc72177626 already downloaded
# Event nc51221693 already downloaded
# Event nc73660911 already downloaded
# Event nc73682211 already downloaded
# Event nc40220087 already downloaded
# Event nc71129735 already downloaded
# Event nc51222070 already downloaded
# Event nc72109725 already downloaded
# Event nc72177616 already downloaded
# Event nc72109965 already downloaded
# Event nc73953050 already downloaded
# Event nc72187621 already downloaded
# Event nc72081521 already downloaded
# Event nc71957055 already downloaded
# Event nc72177611 already downloaded
# Event nc73913801 already downloaded
# Event nc51222072 already downloaded
# Event nc73695251 already downloaded
# Event nc73695266 already downloaded
# Event nc73695506 already downloaded
# Event nc73901451 already downloaded
# Event nc71865635 already downloaded
# Event nc72122005 already downloaded
# Event nc71858965 already downloaded
# Event nc71858955 already downloaded
# Event nc73858110 already downloaded
# Event nc72127186 already downloaded
# Event nc72125526 already downloaded
# Event nc72122010 already downloaded
# Event nc73883011 already downloaded
# Event nc72177601 already downloaded
# Event nc71848200 already downloaded
# Event nc72247101 already downloaded
# Event nc72590875 already downloaded
# Event nc73139126 already downloaded
# Event nc72187866 already downloaded
# Event nc72188081 already downloaded
# Event nc72188301 already downloaded
# Event nc72188586 already downloaded
# Event nc71081449 already downloaded
# Event nc72188626 already downloaded
# Event nc72188661 already downloaded
# Event nc73177520 already downloaded
# Event nc72212126 already downloaded
# Event nc72185220 already downloaded
# Event nc73533631 already downloaded
# Event nc72185280 already downloaded
# Event nc72185375 already downloaded
# Event nc71360785 already downloaded
# Event nc72189880 already downloaded
# Event nc72190295 already downloaded
# Event nc73549625 already downloaded
# Event nc72190520 already downloaded
# Event nc72187851 already downloaded
# Event nc72187681 already downloaded
# Event nc73379705 already downloaded
# Event nc73380030 already downloaded
# Event nc73379725 already downloaded
# Event nc73380035 already downloaded
# Event nc73289140 already downloaded
# Event nc73284120 already downloaded
# Event nc71346896 already downloaded
# Event nc72187831 already downloaded
# Event nc73316301 already downloaded
# Event nc72238921 already downloaded
# Event nc73262485 already downloaded
# Event nc71358400 already downloaded
# Event nc71912736 already downloaded
# Event nc72196165 already downloaded
# Event nc72187661 already downloaded
# Event nc73591566 already downloaded
# Event nc73282790 already downloaded
# Event nc73464291 already downloaded
# Event nc72187856 already downloaded
# Event nc71327600 already downloaded
# Event nc73025341 already downloaded
# Event nc73024426 already downloaded
# Event nc73020480 already downloaded
# Event nc72448611 already downloaded
# Event nc72850501 already downloaded
# Event nc72803286 already downloaded
# Event nc72793316 already downloaded
# Event nc73139066 already downloaded
# Event nc72785826 already downloaded
# Event nc72567886 already downloaded
# Event nc72770921 already downloaded
# Event nc72571026 already downloaded
# Event nc72572376 already downloaded
# Event nc71679881 already downloaded
# Event nc73139111 already downloaded
# Event nc73139116 already downloaded
# Event nc72785701 already downloaded
# Event nc72191150 already downloaded
# Event nc72395440 already downloaded
# Event nc72377506 already downloaded
# Event nc73430611 already downloaded
# Event nc72196150 already downloaded
# Event nc72185210 already downloaded
# Event nc72188125 already downloaded
# Event nc73140470 already downloaded
# Event nc73194936 already downloaded
# Event nc73139041 already downloaded
# Event nc72390536 already downloaded
# Event nc73138106 already downloaded
# Event nc72296351 already downloaded
# Event nc73133251 already downloaded
# Event nc73133256 already downloaded
# Event nc71688186 already downloaded
# Event nc73106061 already downloaded
# Event nc73104941 already downloaded
# Event nc73081690 already downloaded
# Event nc73133341 already downloaded
# Event nc72981086 already downloaded
# Event nc73718040 already downloaded
# Event nc40215740 already downloaded
# Event nc71128770 already downloaded
# Event nc72470121 already downloaded
# Event nc71188825 already downloaded
# Event nc72808181 already downloaded
# Event nc71339731 already downloaded
# Event nc71341326 already downloaded
# Event nc71357556 already downloaded
# Event nc73408161 already downloaded
# Event nc72383101 already downloaded
# Event nc73485746 already downloaded
# Event nc71575830 already downloaded
# Event nc72108385 already downloaded
# Event nc73121410 already downloaded
# Event nc73105386 already downloaded
# Event nc73078865 already downloaded
# Event nc73079215 already downloaded
# Event nc73079210 already downloaded
# Event nc73397621 already downloaded
# Event nc71407421 already downloaded
# Event nc73201196 already downloaded
# Event nc71680150 already downloaded
# Event nc73331491 already downloaded
# Event nc73735891 already downloaded
# Event nc73515515 already downloaded
# Event nc71587015 already downloaded
# Event nc73477306 already downloaded
# Event nc73341335 already downloaded
# Event nc73336226 already downloaded
# Event nc73336276 already downloaded
# Event nc73289160 already downloaded
# Event nc73685486 already downloaded
# Event nc71169161 already downloaded
# Event nc73336291 already downloaded
# Event nc73336296 already downloaded
# Event nc72405815 already downloaded
# Event nc73216121 already downloaded
# Event nc72994510 already downloaded
# Event nc72241846 already downloaded
# Event nc71487220 already downloaded
# Event nc71422405 already downloaded
# Event nc73174025 already downloaded
# Event nc73767160 already downloaded
# Event nc73201166 already downloaded
# Event nc72004665 already downloaded
# Event nc72008505 already downloaded
# Event nc73909801 already downloaded
# Event nc73119001 already downloaded
# Event nc71587020 already downloaded
# Event nc72718125 already downloaded
# Event nc71919551 already downloaded
# Event nc71541725 already downloaded
# Event nc72769811 already downloaded
# Event nc73201181 already downloaded
# Event nc71877765 already downloaded
# Event nc72562611 already downloaded
# Event nc73944271 already downloaded
# Event nc72785941 already downloaded
# Event nc73944166 already downloaded
# Event nc71980360 already downloaded
# Event nc72820761 already downloaded
# Event nc71980540 already downloaded
# Event nc72839026 already downloaded
# Event nc71980370 already downloaded
# Event nc71980445 already downloaded
# Event nc71510245 already downloaded
# Event nc72769836 already downloaded
# Event nc72378641 already downloaded
# Event nc71439571 already downloaded
# Event nc73153771 already downloaded
# Event nc72908441 already downloaded
# Event nc71736811 already downloaded
# Event nc71482146 already downloaded
# Event nc71439791 already downloaded
# Event nc71364810 already downloaded
# Event nc71523376 already downloaded
# Event nc73535191 already downloaded
# Event nc71137085 already downloaded
# Event nc71197890 already downloaded
# Event nc71155436 already downloaded
# Event nc71199035 already downloaded
# Event nc73815786 already downloaded
# Event nc71351911 already downloaded
# Event nc72935406 already downloaded
# Event nc72935821 already downloaded
# Event nc73747806 already downloaded
# Event nc72336776 already downloaded
# Event nc73850141 already downloaded
# Event nc72935551 already downloaded
# Event nc73887531 already downloaded
# Event nc71269601 already downloaded
# Event nc73836866 already downloaded
# Event nc73097426 already downloaded
# Event nc73097411 already downloaded
# Event nc71335736 already downloaded
# Event nc71340591 already downloaded
# Event nc73469511 already downloaded
# Event nc72809646 already downloaded
# Event nc51207076 already downloaded
# Event nc51210202 already downloaded
# Event nc71267951 already downloaded
# Event nc73112486 already downloaded
# Event nc51210163 already downloaded
# Event nc71246061 already downloaded
# Event nc72220461 already downloaded
# Event nc73882946 already downloaded
# Event nc72056956 already downloaded
# Event nc71823611 already downloaded
# Event nc73141715 already downloaded
# Event nc73293750 already downloaded
# Event nc73293765 already downloaded
# Event nc73307986 already downloaded
# Event nc73657510 already downloaded
# Event nc72388111 already downloaded
# Event nc72385936 already downloaded
# Event nc73695851 already downloaded
# Event nc72727755 already downloaded
# Event nc73657500 already downloaded
# Event nc73321206 already downloaded
# Event nc73134881 already downloaded
# Event nc73180910 already downloaded
# Event nc72093561 already downloaded
# Event nc72105091 already downloaded
# Event nc73703681 already downloaded
# Event nc71815591 already downloaded
# Event nc73820866 already downloaded
# Event nc73695871 already downloaded
# Event nc73197761 already downloaded
# Event nc73396966 already downloaded
# Event nc73396951 already downloaded
# Event nc73165425 already downloaded
# Event nc73761206 already downloaded
# Event nc73168640 already downloaded
# Event nc73761211 already downloaded
# Event nc40215417 already downloaded
# Event nc73546990 already downloaded
# Event nc73661611 already downloaded
# Event nc72531161 already downloaded
# Event nc71916311 already downloaded
# Event nc73629686 already downloaded
# Event nc71417121 already downloaded
# Event nc71596070 already downloaded
# Event nc72790391 already downloaded
# Event nc73630191 already downloaded
# Event nc72703011 already downloaded
# Event nc72400020 already downloaded
# Event nc73422076 already downloaded
# Event nc72430441 already downloaded
# Event nc71988416 already downloaded
# Event nc72419005 already downloaded
# Event nc71568361 already downloaded
# Event nc72869185 already downloaded
# Event nc71418340 already downloaded
# Event nc73965026 already downloaded
# Event nc72884515 already downloaded
# Event nc71498305 already downloaded
# Event nc72895726 already downloaded
# Event nc72895731 already downloaded
# Event nc73933351 already downloaded
# Event nc72905946 already downloaded
# Event nc71777240 already downloaded
# Event nc73525576 already downloaded
# Event nc71788691 already downloaded
# Event nc71480081 already downloaded
# Event nc72144765 already downloaded
# Event nc72468136 already downloaded
# Event nc73923506 already downloaded
# Event nc72749820 already downloaded
# Event nc72273535 already downloaded
# Event nc51221033 already downloaded
# Event nc72016185 already downloaded
# Event nc72735750 already downloaded
# Event nc73889561 already downloaded
# Event nc71680185 already downloaded
# Event nc73374815 already downloaded
# Event nc73833291 already downloaded
# Event nc73828311 already downloaded
# Event nc73826661 already downloaded
# Event nc73822836 already downloaded
# Event nc73822711 already downloaded
# Event nc40238305 already downloaded
# Event nc71129529 already downloaded
# Event nc73822246 already downloaded
# Event nc73821741 already downloaded
# Event nc73821071 already downloaded
# Event nc72236026 already downloaded
# Event nc73821696 already downloaded
# Event nc73822516 already downloaded
# Event nc73396641 already downloaded
# Event nc72524981 already downloaded
# Event nc72235746 already downloaded
# Event nc73889801 already downloaded
# Event nc72236031 already downloaded
# Event nc72236276 already downloaded
# Event nc73139521 already downloaded
# Event nc73139526 already downloaded
# Event nc72258166 already downloaded
# Event nc72236716 already downloaded
# Event nc73535101 already downloaded
# Event nc51194666 already downloaded
# Event nc72187451 already downloaded
# Event nc71643091 already downloaded
# Event nc72267071 already downloaded
# Event nc73562750 already downloaded
# Event nc71566861 already downloaded
# Event nc72178546 already downloaded
# Event nc72240921 already downloaded
# Event nc73029301 already downloaded
# Event nc71875120 already downloaded
# Event nc72079471 already downloaded
# Event nc51211012 already downloaded
# Event nc72620265 already downloaded
# Event nc71383971 already downloaded
# Event nc73939161 already downloaded
# Event nc71383806 already downloaded
# Event nc73948875 already downloaded
# Event nc71719045 already downloaded
# Event nc71988536 already downloaded
# Event nc73945676 already downloaded
# Event nc72281726 already downloaded
# Event nc73921286 already downloaded
# Event nc73924166 already downloaded
# Event nc72944166 already downloaded
# Event nc73714596 already downloaded
# Event nc73913736 already downloaded
# Event nc73709221 already downloaded
# Event nc73714841 already downloaded
# Event nc73686011 already downloaded
# Event nc73841256 already downloaded
# Event nc40231888 already downloaded
# Event nc73428831 already downloaded
# Event nc73428826 already downloaded
# Event nc73563250 already downloaded
# Event nc73130186 already downloaded
# Event nc73112611 already downloaded
# Event nc73334331 already downloaded
# Event nc73563565 already downloaded
# Event nc73311641 already downloaded
# Event nc73768295 already downloaded
# Event nc73703226 already downloaded
# Event nc40220580 already downloaded
# Event nc71951585 already downloaded
# Event nc72444386 already downloaded
# Event nc72444571 already downloaded
# Event nc72349376 already downloaded
# Event nc72415885 already downloaded
# Event nc71593615 already downloaded
# Event nc71774710 already downloaded
# Event nc40221295 already downloaded
# Event nc72070661 already downloaded
# Event nc71829666 already downloaded
# Event nc71995896 already downloaded
# Event nc71650576 already downloaded
# Event nc73347425 already downloaded
# Event nc73311701 already downloaded
# Event nc72944231 already downloaded
# Event nc72791686 already downloaded
# Event nc73982056 already downloaded
# Event nc72444356 already downloaded
# Event nc73328466 already downloaded
# Event nc40232406 already downloaded
# Event nc71259711 already downloaded
# Event nc73178780 already downloaded
# Event nc72966651 already downloaded
# Event nc72731930 already downloaded
# Event nc72015675 already downloaded
# Event nc73636440 already downloaded
# Event nc72990650 already downloaded
# Event nc72554506 already downloaded
# Event nc40232592 already downloaded
# Event nc40221128 already downloaded
# Event nc40221138 already downloaded
# Event nc73821726 already downloaded
# Event nc72290906 already downloaded
# Event nc72947931 already downloaded
# Event nc73821551 already downloaded
# Event nc40214567 already downloaded
# Event nc73821296 already downloaded
# Event nc72662681 already downloaded
# Event nc73819026 already downloaded
# Event nc73951985 already downloaded
# Event nc73854886 already downloaded
# Event nc71104386 already downloaded
# Event nc72535831 already downloaded
# Event nc73924291 already downloaded
# Event nc72258726 already downloaded
# Event nc73144721 already downloaded
# Event nc73412801 already downloaded
# Event nc73775750 already downloaded
# Event nc71539606 already downloaded
# Event nc72570136 already downloaded
# Event nc73074570 already downloaded
# Event nc72142740 already downloaded
# Event nc73753416 already downloaded
# Event nc73079260 already downloaded
# Event nc73611556 already downloaded
# Event nc71616480 already downloaded
# Event nc72599715 already downloaded
# Event nc71616450 already downloaded
# Event nc73473046 already downloaded
# Event nc71836901 already downloaded
# Event nc71665216 already downloaded
# Event nc72138971 already downloaded
# Event nc73678171 already downloaded
# Event nc71616455 already downloaded
# Event nc40227240 already downloaded
# Event nc73640160 already downloaded
# Event nc71698420 already downloaded
# Event nc73936326 already downloaded
# Event nc73541626 already downloaded
# Event nc40215840 already downloaded
# Event nc71458915 already downloaded
# Event nc72722260 already downloaded
# Event nc71481066 already downloaded
# Event nc73153956 already downloaded
# Event nc73677921 already downloaded
# Event nc73677916 already downloaded
# Event nc72184761 already downloaded
# Event nc71897516 already downloaded
# Event nc71676066 already downloaded
# Event nc71418180 already downloaded
# Event nc71889651 already downloaded
# Event nc71366840 already downloaded
# Event nc72118405 already downloaded
# Event nc71919066 already downloaded
# Event nc51196872 already downloaded
# Event nc73136551 already downloaded
# Event nc73946486 already downloaded
# Event nc72633185 already downloaded
# Event nc73025696 already downloaded
# Event nc72708186 already downloaded
# Event nc73911986 already downloaded
# Event nc73025281 already downloaded
# Event nc72799581 already downloaded
# Event nc72012600 already downloaded
# Event nc73819356 already downloaded
# Event nc71793601 already downloaded
# Event nc73111381 already downloaded
# Event nc73332721 already downloaded
# Event nc73891980 already downloaded
# Event nc72400565 already downloaded
# Event nc72729525 already downloaded
# Event nc71630780 already downloaded
# Event nc71317300 already downloaded
# Event nc72189495 already downloaded
# Event nc73964546 already downloaded
# Event nc72721780 already downloaded
# Event nc40226338 already downloaded
# Event nc71100926 already downloaded
# Event nc72652971 already downloaded
# Event nc71093761 already downloaded
# Event nc72204480 already downloaded
# Event nc72688106 already downloaded
# Event nc72932790 already downloaded
# Event nc72177681 already downloaded
# Event nc73104151 already downloaded
# Event nc73016880 already downloaded
# Event nc73024456 already downloaded
# Event nc72095756 already downloaded
# Event nc72015405 already downloaded
# Event nc73702741 already downloaded
# Event nc72680411 already downloaded
# Event nc71872550 already downloaded
# Event nc73740886 already downloaded
# Event nc73067710 already downloaded
# Event nc73566565 already downloaded
# Event nc72428825 already downloaded
# Event nc71680355 already downloaded
# Event nc73648540 already downloaded
# Event nc73561530 already downloaded
# Event nc73141120 already downloaded
# Event nc72783636 already downloaded
# Event nc72783931 already downloaded
# Event nc73133291 already downloaded
# Event nc73379325 already downloaded
# Event nc73568876 already downloaded
# Event nc73648130 already downloaded
# Event nc71632785 already downloaded
# Event nc72014450 already downloaded
# Event nc72404695 already downloaded
# Event nc73051361 already downloaded
# Event nc73465461 already downloaded
# Event nc73899256 already downloaded
# Event nc73049201 already downloaded
# Event nc73768410 already downloaded
# Event nc40221171 already downloaded
# Event nc73170980 already downloaded
# Event nc73049236 already downloaded
# Event nc73730291 already downloaded
# Event nc71693141 already downloaded
# Event nc73089681 already downloaded
# Event nc73099376 already downloaded
# Event nc73102186 already downloaded
# Event nc72320401 already downloaded
# Event nc73954610 already downloaded
# Event nc73173620 already downloaded
# Event nc71570815 already downloaded
# Event nc73730296 already downloaded
# Event nc71062519 already downloaded
# Event nc73461586 already downloaded
# Event nc51211334 already downloaded
# Event nc73406476 already downloaded
# Event nc72153556 already downloaded
# Event nc71247711 already downloaded
# Event nc71255501 already downloaded
# Event nc72863516 already downloaded
# Event nc72483811 already downloaded
# Event nc71255526 already downloaded
# Event nc72588661 already downloaded
# Event nc71775065 already downloaded
# Event nc71255551 already downloaded
# Event nc51199341 already downloaded
# Event nc71255986 already downloaded
# Event nc40215622 already downloaded
# Event nc73256800 already downloaded
# Event nc72688941 already downloaded
# Event nc71397951 already downloaded
# Event nc72904996 already downloaded
# Event nc71840620 already downloaded
# Event nc72904646 already downloaded
# Event nc73617246 already downloaded
# Event nc72390166 already downloaded
# Event nc72398060 already downloaded
# Event nc71595020 already downloaded
# Event nc71898151 already downloaded
# Event nc73905196 already downloaded
# Event nc72848256 already downloaded
# Event nc51207731 already downloaded
# Event nc73571131 already downloaded
# Event nc71391921 already downloaded
# Event nc71888456 already downloaded
# Event nc71105674 already downloaded
# Event nc72654286 already downloaded
# Event nc73647855 already downloaded
# Event nc73600171 already downloaded
# Event nc73579836 already downloaded
# Event nc73577995 already downloaded
# Event nc73033931 already downloaded
# Event nc73161300 already downloaded
# Event nc73129211 already downloaded
# Event nc73657175 already downloaded
# Event nc72987806 already downloaded
# Event nc72934385 already downloaded
# Event nc73285770 already downloaded
# Event nc73657470 already downloaded
# Event nc73718430 already downloaded
# Event nc71964105 already downloaded
# Event nc73717951 already downloaded
# Event nc73718400 already downloaded
# Event nc73781676 already downloaded
# Event nc73800731 already downloaded
# Event nc73851681 already downloaded
# Event nc73881061 already downloaded
# Event nc73971131 already downloaded
# Event nc72336831 already downloaded
# Event nc72186870 already downloaded
# Event nc51193680 already downloaded
# Event nc72919501 already downloaded
# Event nc73662861 already downloaded
# Event nc72915371 already downloaded
# Event nc73713091 already downloaded
# Event nc72623045 already downloaded
# Event nc72816546 already downloaded
# Event nc71263101 already downloaded
# Event nc51194589 already downloaded
# Event nc51196020 already downloaded
# Event nc71267871 already downloaded
# Event nc71687456 already downloaded
# Event nc71590175 already downloaded
# Event nc71800606 already downloaded
# Event nc71365895 already downloaded
# Event nc71844945 already downloaded
# Event nc71844930 already downloaded
# Event nc40216664 already downloaded
# Event nc71800566 already downloaded
# Event nc71247611 already downloaded
# Event nc72452261 already downloaded
# Event nc71800621 already downloaded
# Event nc72348066 already downloaded
# Event nc73420671 already downloaded
# Event nc72590081 already downloaded
# Event nc40216665 already downloaded
# Event nc72401530 already downloaded
# Event nc40216667 already downloaded
# Event nc71773775 already downloaded
# Event nc71358615 already downloaded
# Event nc71837465 already downloaded
# Event nc71261106 already downloaded
# Event nc73118836 already downloaded
# Event nc71979355 already downloaded
# Event nc73791326 already downloaded
# Event nc71765835 already downloaded
# Event nc71892006 already downloaded
# Event nc72110581 already downloaded
# Event nc51215473 already downloaded
# Event nc73383905 already downloaded
# Event nc72662366 already downloaded
# Event nc72646276 already downloaded
# Event nc51215717 already downloaded
# Event nc72071421 already downloaded
# Event nc73349820 already downloaded
# Event nc71280511 already downloaded
# Event nc72484671 already downloaded
# Event nc71246116 already downloaded
# Event nc71652046 already downloaded
# Event nc51221590 already downloaded
# Event nc72135941 already downloaded
# Event nc73630526 already downloaded
# Event nc73127696 already downloaded
# Event nc72050586 already downloaded
# Event nc71065069 already downloaded
# Event nc71133260 already downloaded
# Event nc71491130 already downloaded
# Event nc71821266 already downloaded
# Event nc72175591 already downloaded
# Event nc73768770 already downloaded
# Event nc73855970 already downloaded
# Event nc40238256 already downloaded
# Event nc71106981 already downloaded
# Event nc71268451 already downloaded
# Event nc72616305 already downloaded
# Event nc73497580 already downloaded
# Event nc73929636 already downloaded
# Event nc73457786 already downloaded
# Event nc51207840 already downloaded
# Event nc51207829 already downloaded
# Event nc51202870 already downloaded
# Event nc71271580 already downloaded
# Event nc71294686 already downloaded
# Event nc71294371 already downloaded
# Event nc73457811 already downloaded
# Event nc73704711 already downloaded
# Event nc73350095 already downloaded
# Event nc73933386 already downloaded
# Event nc51194828 already downloaded
# Event nc73933646 already downloaded
# Event nc73934141 already downloaded
# Event nc72879845 already downloaded
# Event nc71295726 already downloaded
# Event nc71825131 already downloaded
# Event nc72233276 already downloaded
# Event nc71766385 already downloaded
# Event nc72322191 already downloaded
# Event nc71295721 already downloaded
# Event nc72322146 already downloaded
# Event nc72284206 already downloaded
# Event nc73875585 already downloaded
# Event nc73084915 already downloaded
# Event nc73844891 already downloaded
# Event nc72946846 already downloaded
# Event nc72604915 already downloaded
# Event nc71319956 already downloaded
# Event nc72655856 already downloaded
# Event nc71565381 already downloaded
# Event nc71913236 already downloaded
# Event nc72529026 already downloaded
# Event nc73495120 already downloaded
# Event nc73550505 already downloaded
# Event nc73751651 already downloaded
# Event nc72574490 already downloaded
# Event nc73024816 already downloaded
# Event nc71488095 already downloaded
# Event nc51210909 already downloaded
# Event nc51210912 already downloaded
# Event nc73685336 already downloaded
# Event nc71916401 already downloaded
# Event nc72765451 already downloaded
# Event nc73467776 already downloaded
# Event nc71764090 already downloaded
# Event nc72847541 already downloaded
# Event nc73176765 already downloaded
# Event nc73269800 already downloaded
# Event nc73270265 already downloaded
# Event nc72214776 already downloaded
# Event nc71256511 already downloaded
# Event nc73125226 already downloaded
# Event nc72638100 already downloaded
# Event nc71915126 already downloaded
# Event nc72071921 already downloaded
# Event nc72911481 already downloaded
# Event nc71422870 already downloaded
# Event nc71445405 already downloaded
# Event nc72755240 already downloaded
# Event nc72558871 already downloaded
# Event nc73237836 already downloaded
# Event nc72109695 already downloaded
# Event nc73427541 already downloaded
# Event nc72598785 already downloaded
# Event nc72596780 already downloaded
# Event nc73469741 already downloaded
# Event nc71464810 already downloaded
# Event nc71349716 already downloaded
# Event nc73565810 already downloaded
# Event nc40231748 already downloaded
# Event nc40221060 already downloaded
# Event nc73844406 already downloaded
# Event nc71256386 already downloaded
# Event nc73504005 already downloaded
# Event nc73544605 already downloaded
# Event nc73512175 already downloaded
# Event nc72008315 already downloaded
# Event nc73579566 already downloaded
# Event nc71255406 already downloaded
# Event nc71841515 already downloaded
# Event nc40234475 already downloaded
# Event nc72342070 already downloaded
# Event nc73739276 already downloaded
# Event nc73739351 already downloaded
# Event nc73754731 already downloaded
# Event nc73773785 already downloaded
# Event nc73582966 already downloaded
# Event nc73939156 already downloaded
# Event nc51197189 already downloaded
# Event nc71240486 already downloaded
# Event nc73968381 already downloaded
# Event nc71764775 already downloaded
# Event nc72201600 already downloaded
# Event nc73481056 already downloaded
# Event nc71953780 already downloaded
# Event nc71684226 already downloaded
# Event nc71990966 already downloaded
# Event nc72091856 already downloaded
# Event nc51202893 already downloaded
# Event nc72154546 already downloaded
# Event nc72257996 already downloaded
# Event nc72192490 already downloaded
# Event nc72316851 already downloaded
# Event nc72006045 already downloaded
# Event nc72006040 already downloaded
# Event nc72006070 already downloaded
# Event nc40234034 already downloaded
# Event nc73783916 already downloaded
# Event nc40220954 already downloaded
# Event nc73684886 already downloaded
# Event nc73684826 already downloaded
# Event nc40220957 already downloaded
# Event nc73684786 already downloaded
# Event nc51197782 already downloaded
# Event nc73684591 already downloaded
# Event nc73619256 already downloaded
# Event nc73684906 already downloaded
# Event nc73683751 already downloaded
# Event nc73783946 already downloaded
# Event nc73683711 already downloaded
# Event nc73684891 already downloaded
# Event nc73684671 already downloaded
# Event nc73812326 already downloaded
# Event nc73783971 already downloaded
# Event nc73783941 already downloaded
# Event nc73812746 already downloaded
# Event nc72620700 already downloaded
# Event nc73786101 already downloaded
# Event nc73478521 already downloaded
# Event nc72159811 already downloaded
# Event nc73692936 already downloaded
# Event nc73692101 already downloaded
# Event nc72626515 already downloaded
# Event nc73783911 already downloaded
# Event nc73685641 already downloaded
# Event nc73685406 already downloaded
# Event nc73783921 already downloaded
# Event nc51220922 already downloaded
# Event nc72074156 already downloaded
# Event nc72773131 already downloaded
# Event nc40232766 already downloaded
# Event nc72641551 already downloaded
# Event nc73885286 already downloaded
# Event nc40218352 already downloaded
# Event nc73617261 already downloaded
# Event nc73040931 already downloaded
# Event nc73074931 already downloaded
# Event nc72493581 already downloaded
# Event nc71778485 already downloaded
# Event nc71993336 already downloaded
# Event nc71634355 already downloaded
# Using existing inventory
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (884, 'nc72117960'):169. Took 17.01 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (885, 'nc72322446'):205. Took 17.02 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (886, 'nc73076250'):197. Took 16.68 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (887, 'nc73074680'):193. Took 14.69 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (888, 'nc72318396'):201. Took 16.58 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (889, 'nc73683196'):235. Took 18.52 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (890, 'nc72090751'):169. Took 16.23 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (891, 'nc72941716'):186. Took 16.14 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (892, 'nc72074151'):170. Took 14.70 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (893, 'nc71388040'):117. Took 12.61 seconds
# Event nc73316461 already downloaded
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (895, 'nc72736795'):154. Took 14.99 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (896, 'nc51203864'):157. Took 14.13 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (897, 'nc51222078'):137. Took 14.29 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (898, 'nc71958960'):200. Took 16.95 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (899, 'nc72318721'):203. Took 15.87 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (900, 'nc51207671'):152. Took 12.63 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (901, 'nc71842710'):173. Took 21.03 seconds
# Event nc73255220 already downloaded
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (903, 'nc72909621'):168. Took 14.40 seconds
# Event nc51207214 already downloaded
# Event nc72942761 already downloaded
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (906, 'nc72895391'):150. Took 12.40 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (907, 'nc73659055'):221. Took 17.99 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (908, 'nc72705351'):143. Took 12.84 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (909, 'nc73619486'):205. Took 14.88 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (910, 'nc72706951'):138. Took 12.46 seconds
# Event nc40238541 already downloaded
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (912, 'nc40231307'):134. Took 14.35 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (913, 'nc73955565'):239. Took 17.91 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (914, 'nc73782386'):223. Took 15.14 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (915, 'nc72484636'):182. Took 13.52 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (916, 'nc72461801'):187. Took 15.59 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (917, 'nc71108755'):127. Took 12.90 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (918, 'nc72746035'):125. Took 11.99 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')
# Download complete for (919, 'nc71650676'):87. Took 9.96 seconds
# Download complete for (920, 'nc71138195'):111. Took 10.12 seconds
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:821: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# /Users/mdaislam/anaconda3/envs/obspy/lib/python3.10/site-packages/obspy/io/mseed/core.py:823: UserWarning: File will be written with more than one different record lengths.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'record lengths')

# %%
mseed_files = [f for f in os.listdir(waveform_dir) if f.endswith('.mseed')]
print(len(mseed_files))
# Out:
# 921

# %%
# # gather all the stationtxt files into one
# stationtxt_files = os.listdir(f"{waveform_dir}/inv_txt")

# # read all the stationtxt files into one dataframe
# stationtxt_df = pd.concat([pd.read_csv(f"{waveform_dir}/inv_txt/{f}", sep='|') for f in stationtxt_files])

# # drop duplicates
# stationtxt_df = stationtxt_df.sort_values(by=['#Network', 'Station', 'Channel'])
# stationtxt_df = stationtxt_df.drop_duplicates(subset=['#Network', 'Station', 'Channel'], keep='last')

# # save the stationtxt file
# stationtxt_df.to_csv(f"{data_dir}/3_station_catalogs/00_station_inventory_921.txt", sep='|', index=False)

# # read the stationtxt file
# station_inv = read_inventory(f"{data_dir}/3_station_catalogs/00_station_inventory_921.txt", format="STATIONTXT")
# station_inv.write(f"{data_dir}/3_station_catalogs/00_station_inventory_921.xml", format="STATIONXML")
